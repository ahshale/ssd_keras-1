# %% [markdown]
# # SSD300 Training Tutorial
#
# This tutorial explains how to train an SSD300 on the Pascal VOC datasets. The preset parameters reproduce the training of the original SSD300 "07+12" model. Training SSD512 works simiarly, so there's no extra tutorial for that. The same goes for training on other datasets.
#
# You can find a summary of a full training here to get an impression of what it should look like:
# [SSD300 "07+12" training summary](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md)

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from models.keras_ssd512 import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 0. Preliminary note
#
# All places in the code where you need to make any changes are marked `TODO` and explained accordingly. All code cells that don't contain `TODO` markers just need to be executed.

# %% [markdown]
# ## 1. Set the model configuration parameters
#
# This section sets the configuration parameters for the model definition. The parameters set here are being used both by the `ssd_300()` function that builds the SSD300 model as well as further down by the constructor for the `SSDInputEncoder` object that is needed to run the training. Most of these parameters are needed to define the anchor boxes.
#
# The parameters as set below produce the original SSD300 architecture that was trained on the Pascal VOC datsets, i.e. they are all chosen to correspond exactly to their respective counterparts in the `.prototxt` file that defines the original Caffe implementation. Note that the anchor box scaling factors of the original SSD implementation vary depending on the datasets on which the models were trained. The scaling factors used for the MS COCO datasets are smaller than the scaling factors used for the Pascal VOC datasets. The reason why the list of scaling factors has 7 elements while there are only 6 predictor layers is that the last scaling factor is used for the second aspect-ratio-1 box of the last predictor layer. Refer to the documentation for details.
#
# As mentioned above, the parameters set below are not only needed to build the model, but are also passed to the `SSDInputEncoder` constructor further down, which is responsible for matching and encoding ground truth boxes and anchor boxes during the training. In order to do that, it needs to know the anchor box parameters.

# %%
img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
#img_height = 512 # Height of the model input images
#img_width = 512 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 3 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_pascal
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## 2. Build or load the model
#
# You will want to execute either of the two code cells in the subsequent two sub-sections, not both.

# %% [markdown]
# ### 2.1 Create a new model and load trained VGG-16 weights into it (or trained SSD weights)
#
# If you want to create a new SSD300 model, this is the relevant section for you. If you want to load a previously saved SSD300 model, skip ahead to section 2.2.
#
# The code cell below does the following things:
# 1. It calls the function `ssd_300()` to build the model.
# 2. It then loads the weights file that is found at `weights_path` into the model. You could load the trained VGG-16 weights or you could load the weights of a trained model. If you want to reproduce the original SSD training, load the pre-trained VGG-16 weights. In any case, you need to set the path to the weights file you want to load on your local machine. Download links to all the trained weights are provided in the [README](https://github.com/pierluigiferrari/ssd_keras/blob/master/README.md) of this repository.
# 3. Finally, it compiles the model for the training. In order to do so, we're defining an optimizer (Adam) and a loss function (SSDLoss) to be passed to the `compile()` method.
#
# Normally, the optimizer of choice would be Adam (commented out below), but since the original implementation uses plain SGD with momentum, we'll do the same in order to reproduce the original training. Adam is generally the superior optimizer, so if your goal is not to have everything exactly as in the original training, feel free to switch to Adam. You might need to adjust the learning rate scheduler below slightly in case you use Adam.
#
# Note that the learning rate that is being set here doesn't matter, because further below we'll pass a learning rate scheduler to the training function, which will overwrite any learning rate set here, i.e. what matters are the learning rates that are defined by the learning rate scheduler.
#
# `SSDLoss` is a custom Keras loss function that implements the multi-task that consists of a log loss for classification and a smooth L1 loss for localization. `neg_pos_ratio` and `alpha` are set as in the paper.

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.


model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)
"""
model = ssd_512(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                #scales=[0.07, 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, 1.05], # The scales for MS COCO are 
                scales=[0.04, 0.1, 0.26, 0.42, 0.58, 0.74, 0.9, 1.06],
                aspect_ratios_per_layer=[[1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5]],
               two_boxes_for_ar1=True,
               steps=[8, 16, 32, 64, 128, 256, 512],
               offsets=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
               clip_boxes=False,
               variances=[0.1, 0.1, 0.2, 0.2],
               normalize_coords=True,
               subtract_mean=mean_color,
               swap_channels=[2, 1, 0])
"""

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
weights_path = r'D:\xgll\ssd_keras_weights\VGG_coco_SSD_300x300_iter_400000_subsampled_3_classes.h5'
#weights_path = r'D:\xgll\ssd_keras_weights\VGG_coco_SSD_512x512_iter_360000_subsampled_3_classes.h5'

model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
#sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

#model.compile(optimizer=sgd, loss=ssd_loss.compute_loss)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %% [markdown]
# ### 2.2 Load a previously created model
#
# If you have previously created and saved a model and would now like to load it, execute the next code cell. The only thing you need to do here is to set the path to the saved model HDF5 file that you would like to load.
#
# The SSD model contains custom objects: Neither the loss function nor the anchor box or L2-normalization layer types are contained in the Keras core library, so we need to provide them to the model loader.
#
# This next code cell assumes that you want to load a model that was created in 'training' mode. If you want to load a model that was created in 'inference' or 'inference_fast' mode, you'll have to add the `DecodeDetections` or `DecodeDetectionsFast` layer type to the `custom_objects` dictionary below.

# %%
# TODO: Set the path to the `.h5` file of the model to be loaded.
model_path = 'path/to/trained/model.h5'

# We need to create an SSDLoss object in order to pass that to the model loader.
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

K.clear_session() # Clear previous models from memory.

model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                               'L2Normalization': L2Normalization,
                                               'compute_loss': ssd_loss.compute_loss})

# %% [markdown]
# ## 3. Set up the data generators for the training
#
# The code cells below set up the data generators for the training and validation datasets to train the model. The settings below reproduce the original SSD training on Pascal VOC 2007 `trainval` plus 2012 `trainval` and validation on Pascal VOC 2007 `test`.
#
# The only thing you need to change here are the filepaths to the datasets on your local machine. Note that parsing the labels from the XML annotations files can take a while.
#
# Note that the generator provides two options to speed up the training. By default, it loads the individual images for a batch from disk. This has two disadvantages. First, for compressed image formats like JPG, this is a huge computational waste, because every image needs to be decompressed again and again every time it is being loaded. Second, the images on disk are likely not stored in a contiguous block of memory, which may also slow down the loading process. The first option that `DataGenerator` provides to deal with this is to load the entire dataset into memory, which reduces the access time for any image to a negligible amount, but of course this is only an option if you have enough free memory to hold the whole dataset. As a second option, `DataGenerator` provides the possibility to convert the dataset into a single HDF5 file. This HDF5 file stores the images as uncompressed arrays in a contiguous block of memory, which dramatically speeds up the loading time. It's not as good as having the images in memory, but it's a lot better than the default option of loading them from their compressed JPG state every time they are needed. Of course such an HDF5 dataset may require significantly more disk space than the compressed images (around 9 GB total for Pascal VOC 2007 `trainval` plus 2012 `trainval` and another 2.6 GB for 2007 `test`). You can later load these HDF5 datasets directly in the constructor.
#
# The original SSD implementation uses a batch size of 32 for the training. In case you run into GPU memory issues, reduce the batch size accordingly. You need at least 7 GB of free GPU memory to train an SSD300 with 20 object classes with a batch size of 32.
#
# The `DataGenerator` itself is fairly generic. I doesn't contain any data augmentation or bounding box encoding logic. Instead, you pass a list of image transformations and an encoder for the bounding boxes in the `transformations` and `label_encoder` arguments of the data generator's `generate()` method, and the data generator will then apply those given transformations and the encoding to the data. Everything here is preset already, but if you'd like to learn more about the data generator and its data augmentation capabilities, take a look at the detailed tutorial in [this](https://github.com/pierluigiferrari/data_generator_object_detection_2d) repository.
#
# The data augmentation settings defined further down reproduce the data augmentation pipeline of the original SSD training. The training generator receives an object `ssd_data_augmentation`, which is a transformation object that is itself composed of a whole chain of transformations that replicate the data augmentation procedure used to train the original Caffe implementation. The validation generator receives an object `resize`, which simply resizes the input images.
#
# An `SSDInputEncoder` object, `ssd_input_encoder`, is passed to both the training and validation generators. As explained above, it matches the ground truth labels to the model's anchor boxes and encodes the box coordinates into the format that the model needs.
#
# In order to train the model on a dataset other than Pascal VOC, either choose `DataGenerator`'s appropriate parser method that corresponds to your data format, or, if `DataGenerator` does not provide a suitable parser for your data format, you can write an additional parser and add it. Out of the box, `DataGenerator` can handle datasets that use the Pascal VOC format (use `parse_xml()`), the MS COCO format (use `parse_json()`) and a wide range of CSV formats (use `parse_csv()`).

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets. This can take a while.

# TODO: Set the paths to the datasets here.

# The directories that contain the images.
VOC_2007_images_dir      = '../../datasets/VOCdevkit/VOC2007/JPEGImages/'
VOC_2012_images_dir      = '../../datasets/VOCdevkit/VOC2012/JPEGImages/'

# The directories that contain the annotations.
VOC_2007_annotations_dir      = '../../datasets/VOCdevkit/VOC2007/Annotations/'
VOC_2012_annotations_dir      = '../../datasets/VOCdevkit/VOC2012/Annotations/'

# The paths to the image sets.
VOC_2007_train_image_set_filename    = '../../datasets/VOCdevkit/VOC2007/ImageSets/Main/train.txt'
VOC_2012_train_image_set_filename    = '../../datasets/VOCdevkit/VOC2012/ImageSets/Main/train.txt'
VOC_2007_val_image_set_filename      = '../../datasets/VOCdevkit/VOC2007/ImageSets/Main/val.txt'
VOC_2012_val_image_set_filename      = '../../datasets/VOCdevkit/VOC2012/ImageSets/Main/val.txt'
VOC_2007_trainval_image_set_filename = '../../datasets/VOCdevkit/VOC2007/ImageSets/Main/trainval.txt'
VOC_2012_trainval_image_set_filename = '../../datasets/VOCdevkit/VOC2012/ImageSets/Main/trainval.txt'
VOC_2007_test_image_set_filename     = '../../datasets/VOCdevkit/VOC2007/ImageSets/Main/test.txt'

# The XML parser needs to now what object class names to look for and in which order to map them to integers.
classes = ['background',
           'aeroplane', 'bicycle', 'bird', 'boat',
           'bottle', 'bus', 'car', 'cat',
           'chair', 'cow', 'diningtable', 'dog',
           'horse', 'motorbike', 'person', 'pottedplant',
           'sheep', 'sofa', 'train', 'tvmonitor']

train_dataset.parse_xml(images_dirs=[VOC_2007_images_dir,
                                     VOC_2012_images_dir],
                        image_set_filenames=[VOC_2007_trainval_image_set_filename,
                                             VOC_2012_trainval_image_set_filename],
                        annotations_dirs=[VOC_2007_annotations_dir,
                                          VOC_2012_annotations_dir],
                        classes=classes,
                        include_classes='all',
                        exclude_truncated=False,
                        exclude_difficult=False,
                        ret=False)

val_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                      image_set_filenames=[VOC_2007_test_image_set_filename],
                      annotations_dirs=[VOC_2007_annotations_dir],
                      classes=classes,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=True,
                      ret=False)

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

train_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07+12_trainval.h5',
                                  resize=False,
                                  variable_image_size=True,
                                  verbose=True)

val_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_test.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)
# Out:
# Processing image set 'trainval.txt': 100%|██████████| 5011/5011 [00:14<00:00, 339.96it/s]
# Processing image set 'trainval.txt': 100%|██████████| 11540/11540 [00:30<00:00, 381.10it/s]
# Loading images into memory: 100%|██████████| 16551/16551 [01:12<00:00, 228.31it/s]
# Processing image set 'test.txt': 100%|██████████| 4952/4952 [00:13<00:00, 367.21it/s]
# Loading images into memory: 100%|██████████| 4952/4952 [00:19<00:00, 260.61it/s]
# Creating HDF5 dataset: 100%|██████████| 16551/16551 [01:48<00:00, 152.80it/s]
# Creating HDF5 dataset: 100%|██████████| 4952/4952 [00:40<00:00, 122.75it/s]

# %%
train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)

# TODO: Set the paths to your dataset here.
classes=['background', 'metal', 'glass', 'stone']

train_dataset.parse_xml(images_dirs=[r'D:\xgll\dataset\dataset_300'],
                  image_set_filenames=[r'D:\xgll\dataset\trainset_ssd.txt'],
                  annotations_dirs=[r'D:\xgll\dataset\xml_300'],
                  classes=classes, # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                  )

val_dataset.parse_xml(images_dirs=[r'D:\xgll\dataset\dataset_300'],
                  image_set_filenames=[r'D:\xgll\dataset\valset_ssd.txt'],
                  annotations_dirs=[r'D:\xgll\dataset\xml_300'],
                  classes=classes, # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                  )

train_dataset.create_hdf5_dataset(file_path=r'D:\xgll\dataset\dataset_mine_train_300.h5',
                                  resize=False,
                                  variable_image_size=True,
                                  verbose=True)

val_dataset.create_hdf5_dataset(file_path=r'D:\xgll\dataset\dataset_mine_val_300.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)
# Out:
# Processing image set 'trainset_ssd.txt': 100%|████████████████████████████████████| 1618/1618 [00:04<00:00, 401.65it/s]
# Processing image set 'valset_ssd.txt': 100%|████████████████████████████████████████| 392/392 [00:00<00:00, 455.17it/s]
# Creating HDF5 dataset: 100%|██████████████████████████████████████████████████████| 1618/1618 [00:10<00:00, 161.14it/s]
# Creating HDF5 dataset: 100%|████████████████████████████████████████████████████████| 392/392 [00:02<00:00, 147.85it/s]

# %%
# 3: Set the batch size.

batch_size = 16 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  1618
# Number of images in the validation dataset:	   392

# %% [markdown]
# ## 4. Set the remaining training parameters
#
# We've already chosen an optimizer and set the batch size above, now let's set the remaining training parameters. I'll set one epoch to consist of 1,000 training steps. The next code cell defines a learning rate schedule that replicates the learning rate schedule of the original Caffe implementation for the training of the SSD300 Pascal VOC "07+12" model. That model was trained for 120,000 steps with a learning rate of 0.001 for the first 80,000 steps, 0.0001 for the next 20,000 steps, and 0.00001 for the last 20,000 steps. If you're training on a different dataset, define the learning rate schedule however you see fit.
#
# I'll set only a few essential Keras callbacks below, feel free to add more callbacks if you want TensorBoard summaries or whatever. We obviously need the learning rate scheduler and we want to save the best models during the training. It also makes sense to continuously stream our training history to a CSV log file after every epoch, because if we didn't do that, in case the training terminates with an exception at some point or if the kernel of this Jupyter notebook dies for some reason or anything like that happens, we would lose the entire history for the trained epochs. Finally, we'll also add a callback that makes sure that the training terminates if the loss becomes `NaN`. Depending on the optimizer you use, it can happen that the loss becomes `NaN` during the first iterations of the training. In later iterations it's less of a risk. For example, I've never seen a `NaN` loss when I trained SSD using an Adam optimizer, but I've seen a `NaN` loss a couple of times during the very first couple of hundred training steps of training a new model when I used an SGD optimizer.

# %%
# Define a learning rate schedule.

def lr_schedule(epoch):
    if epoch < 80:
        return 0.001
    elif epoch < 100:
        return 0.0001
    else:
        return 0.00001

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath=r'D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
#model_checkpoint.best = 

csv_logger = CSVLogger(filename=r'D:\xgll\ssd_keras_weights\coco_train_300\ssd_mine_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %% [markdown]
# ## 5. Train

# %% [markdown]
# In order to reproduce the training of the "07+12" model mentioned above, at 1,000 training steps per epoch you'd have to train for 120 epochs. That is going to take really long though, so you might not want to do all 120 epochs in one go and instead train only for a few epochs at a time. You can find a summary of a full training [here](https://github.com/pierluigiferrari/ssd_keras/blob/master/training_summaries/ssd300_pascal_07%2B12_training_summary.md).
#
# In order to only run a partial training and resume smoothly later on, there are a few things you should note:
# 1. Always load the full model if you can, rather than building a new model and loading previously saved weights into it. Optimizers like SGD or Adam keep running averages of past gradient moments internally. If you always save and load full models when resuming a training, then the state of the optimizer is maintained and the training picks up exactly where it left off. If you build a new model and load weights into it, the optimizer is being initialized from scratch, which, especially in the case of Adam, leads to small but unnecessary setbacks every time you resume the training with previously saved weights.
# 2. In order for the learning rate scheduler callback above to work properly, `fit_generator()` needs to know which epoch we're in, otherwise it will start with epoch 0 every time you resume the training. Set `initial_epoch` to be the next epoch of your training. Note that this parameter is zero-based, i.e. the first epoch is epoch 0. If you had trained for 10 epochs previously and now you'd want to resume the training from there, you'd set `initial_epoch = 10` (since epoch 10 is the eleventh epoch). Furthermore, set `final_epoch` to the last epoch you want to run. To stick with the previous example, if you had trained for 10 epochs previously and now you'd want to train for another 10 epochs, you'd set `initial_epoch = 10` and `final_epoch = 20`.
# 3. In order for the model checkpoint callback above to work correctly after a kernel restart, set `model_checkpoint.best` to the best validation loss from the previous training. If you don't do this and a new `ModelCheckpoint` object is created after a kernel restart, that object obviously won't know what the last best validation loss was, so it will always save the weights of the first epoch of your new training and record that loss as its new best loss. This isn't super-important, I just wanted to mention it.

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 120
steps_per_epoch = 100

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/120
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 25:35 - loss: 494.34 - ETA: 12:56 - loss: 658.33 - ETA: 8:42 - loss: 484.2425 - ETA: 6:35 - loss: 388.174 - ETA: 5:19 - loss: 317.924 - ETA: 4:28 - loss: 270.217 - ETA: 3:52 - loss: 234.936 - ETA: 3:24 - loss: 208.626 - ETA: 3:03 - loss: 187.733 - ETA: 2:45 - loss: 170.784 - ETA: 2:31 - loss: 156.898 - ETA: 2:19 - loss: 145.474 - ETA: 2:09 - loss: 135.640 - ETA: 2:00 - loss: 127.370 - ETA: 1:53 - loss: 120.050 - ETA: 1:52 - loss: 113.629 - ETA: 1:49 - loss: 107.959 - ETA: 1:46 - loss: 103.050 - ETA: 1:44 - loss: 98.607 - ETA: 1:42 - loss: 94.57 - ETA: 1:41 - loss: 90.89 - ETA: 1:39 - loss: 87.54 - ETA: 1:38 - loss: 84.53 - ETA: 1:36 - loss: 81.71 - ETA: 1:35 - loss: 79.13 - ETA: 1:33 - loss: 76.78 - ETA: 1:31 - loss: 74.61 - ETA: 1:30 - loss: 72.57 - ETA: 1:28 - loss: 70.65 - ETA: 1:26 - loss: 68.87 - ETA: 1:24 - loss: 67.20 - ETA: 1:22 - loss: 65.63 - ETA: 1:22 - loss: 64.15 - ETA: 1:20 - loss: 62.76 - ETA: 1:19 - loss: 61.45 - ETA: 1:17 - loss: 60.20 - ETA: 1:16 - loss: 59.02 - ETA: 1:15 - loss: 57.92 - ETA: 1:13 - loss: 56.89 - ETA: 1:12 - loss: 55.87 - ETA: 1:11 - loss: 54.92 - ETA: 1:10 - loss: 54.04 - ETA: 1:09 - loss: 53.23 - ETA: 1:07 - loss: 52.38 - ETA: 1:06 - loss: 51.58 - ETA: 1:05 - loss: 50.85 - ETA: 1:04 - loss: 50.12 - ETA: 1:03 - loss: 49.45 - ETA: 1:02 - loss: 48.77 - ETA: 1:00 - loss: 48.11 - ETA: 59s - loss: 47.4845 - ETA: 58s - loss: 46.897 - ETA: 57s - loss: 46.294 - ETA: 55s - loss: 45.712 - ETA: 54s - loss: 45.153 - ETA: 52s - loss: 44.638 - ETA: 51s - loss: 44.119 - ETA: 49s - loss: 43.627 - ETA: 48s - loss: 43.139 - ETA: 47s - loss: 42.674 - ETA: 45s - loss: 42.214 - ETA: 44s - loss: 41.768 - ETA: 43s - loss: 41.349 - ETA: 42s - loss: 40.937 - ETA: 41s - loss: 40.533 - ETA: 40s - loss: 40.140 - ETA: 38s - loss: 39.765 - ETA: 37s - loss: 39.395 - ETA: 36s - loss: 39.039 - ETA: 35s - loss: 38.693 - ETA: 34s - loss: 38.369 - ETA: 33s - loss: 38.033 - ETA: 31s - loss: 37.711 - ETA: 30s - loss: 37.399 - ETA: 29s - loss: 37.096 - ETA: 28s - loss: 36.802 - ETA: 27s - loss: 36.536 - ETA: 25s - loss: 36.250 - ETA: 24s - loss: 35.979 - ETA: 23s - loss: 35.712 - ETA: 22s - loss: 35.448 - ETA: 21s - loss: 35.193 - ETA: 20s - loss: 34.941 - ETA: 18s - loss: 34.702 - ETA: 17s - loss: 34.477 - ETA: 16s - loss: 34.243 - ETA: 15s - loss: 34.026 - ETA: 14s - loss: 33.806 - ETA: 12s - loss: 33.609 - ETA: 11s - loss: 33.392 - ETA: 10s - loss: 33.194 - ETA: 9s - loss: 33.001 - ETA: 8s - loss: 32.79 - ETA: 7s - loss: 32.60 - ETA: 5s - loss: 32.42 - ETA: 4s - loss: 32.25 - ETA: 3s - loss: 32.06 - ETA: 2s - loss: 31.88 - ETA: 1s - loss: 31.71 - 121s 1s/step - loss: 31.5375 - val_loss: 14.7724
#
# Epoch 00001: val_loss improved from inf to 14.77242, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-01_loss-31.5375_val_loss-14.7724.h5
# Epoch 2/120
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 35s - loss: 15.132 - ETA: 59s - loss: 14.167 - ETA: 49s - loss: 14.157 - ETA: 44s - loss: 14.083 - ETA: 41s - loss: 14.381 - ETA: 38s - loss: 14.307 - ETA: 37s - loss: 14.305 - ETA: 38s - loss: 14.316 - ETA: 47s - loss: 14.454 - ETA: 51s - loss: 14.440 - ETA: 54s - loss: 14.494 - ETA: 58s - loss: 14.482 - ETA: 1:01 - loss: 14.50 - ETA: 1:03 - loss: 14.47 - ETA: 1:06 - loss: 14.49 - ETA: 1:08 - loss: 14.47 - ETA: 1:08 - loss: 14.42 - ETA: 1:08 - loss: 14.46 - ETA: 1:08 - loss: 14.42 - ETA: 1:09 - loss: 14.43 - ETA: 1:09 - loss: 14.39 - ETA: 1:09 - loss: 14.36 - ETA: 1:08 - loss: 14.35 - ETA: 1:08 - loss: 14.39 - ETA: 1:08 - loss: 14.44 - ETA: 1:08 - loss: 14.42 - ETA: 1:08 - loss: 14.41 - ETA: 1:08 - loss: 14.41 - ETA: 1:08 - loss: 14.38 - ETA: 1:07 - loss: 14.37 - ETA: 1:06 - loss: 14.36 - ETA: 1:06 - loss: 14.36 - ETA: 1:05 - loss: 14.35 - ETA: 1:04 - loss: 14.34 - ETA: 1:04 - loss: 14.33 - ETA: 1:04 - loss: 14.34 - ETA: 1:03 - loss: 14.36 - ETA: 1:02 - loss: 14.36 - ETA: 1:02 - loss: 14.33 - ETA: 1:01 - loss: 14.33 - ETA: 1:00 - loss: 14.38 - ETA: 59s - loss: 14.3749 - ETA: 58s - loss: 14.358 - ETA: 57s - loss: 14.344 - ETA: 56s - loss: 14.339 - ETA: 56s - loss: 14.338 - ETA: 56s - loss: 14.346 - ETA: 55s - loss: 14.334 - ETA: 54s - loss: 14.326 - ETA: 53s - loss: 14.322 - ETA: 52s - loss: 14.323 - ETA: 51s - loss: 14.320 - ETA: 50s - loss: 14.323 - ETA: 49s - loss: 14.319 - ETA: 48s - loss: 14.317 - ETA: 47s - loss: 14.331 - ETA: 47s - loss: 14.341 - ETA: 46s - loss: 14.336 - ETA: 44s - loss: 14.326 - ETA: 43s - loss: 14.317 - ETA: 42s - loss: 14.322 - ETA: 42s - loss: 14.302 - ETA: 41s - loss: 14.304 - ETA: 40s - loss: 14.293 - ETA: 39s - loss: 14.298 - ETA: 38s - loss: 14.291 - ETA: 37s - loss: 14.285 - ETA: 36s - loss: 14.281 - ETA: 35s - loss: 14.283 - ETA: 34s - loss: 14.270 - ETA: 33s - loss: 14.263 - ETA: 32s - loss: 14.254 - ETA: 31s - loss: 14.245 - ETA: 30s - loss: 14.242 - ETA: 28s - loss: 14.230 - ETA: 27s - loss: 14.223 - ETA: 26s - loss: 14.210 - ETA: 25s - loss: 14.205 - ETA: 24s - loss: 14.206 - ETA: 23s - loss: 14.223 - ETA: 22s - loss: 14.217 - ETA: 20s - loss: 14.224 - ETA: 19s - loss: 14.213 - ETA: 18s - loss: 14.221 - ETA: 17s - loss: 14.226 - ETA: 16s - loss: 14.220 - ETA: 15s - loss: 14.223 - ETA: 14s - loss: 14.216 - ETA: 13s - loss: 14.215 - ETA: 11s - loss: 14.238 - ETA: 10s - loss: 14.231 - ETA: 9s - loss: 14.225 - ETA: 8s - loss: 14.21 - ETA: 7s - loss: 14.20 - ETA: 6s - loss: 14.19 - ETA: 4s - loss: 14.19 - ETA: 3s - loss: 14.18 - ETA: 2s - loss: 14.18 - ETA: 1s - loss: 14.17 - 131s 1s/step - loss: 14.1893 - val_loss: 14.1393
#
# Epoch 00002: val_loss improved from 14.77242 to 14.13930, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-02_loss-14.1979_val_loss-14.1393.h5
# Epoch 3/120
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 34s - loss: 13.553 - ETA: 42s - loss: 13.630 - ETA: 54s - loss: 13.413 - ETA: 45s - loss: 13.102 - ETA: 1:01 - loss: 13.62 - ETA: 1:32 - loss: 13.70 - ETA: 1:38 - loss: 13.67 - ETA: 1:46 - loss: 14.17 - ETA: 1:48 - loss: 14.07 - ETA: 1:53 - loss: 14.02 - ETA: 1:53 - loss: 13.98 - ETA: 1:55 - loss: 13.96 - ETA: 1:57 - loss: 13.92 - ETA: 2:02 - loss: 13.93 - ETA: 2:01 - loss: 13.95 - ETA: 2:03 - loss: 13.92 - ETA: 2:01 - loss: 13.90 - ETA: 2:03 - loss: 13.87 - ETA: 2:06 - loss: 13.86 - ETA: 2:04 - loss: 13.86 - ETA: 2:04 - loss: 13.86 - ETA: 2:02 - loss: 13.86 - ETA: 2:00 - loss: 13.89 - ETA: 2:00 - loss: 13.88 - ETA: 2:00 - loss: 13.88 - ETA: 2:01 - loss: 13.86 - ETA: 2:00 - loss: 13.85 - ETA: 1:58 - loss: 13.85 - ETA: 1:55 - loss: 13.83 - ETA: 1:52 - loss: 13.82 - ETA: 1:51 - loss: 13.81 - ETA: 1:51 - loss: 13.80 - ETA: 1:51 - loss: 13.84 - ETA: 1:50 - loss: 13.89 - ETA: 1:49 - loss: 13.87 - ETA: 1:46 - loss: 13.85 - ETA: 1:45 - loss: 13.91 - ETA: 1:44 - loss: 13.90 - ETA: 1:42 - loss: 13.93 - ETA: 1:41 - loss: 13.92 - ETA: 1:39 - loss: 13.97 - ETA: 1:37 - loss: 13.98 - ETA: 1:35 - loss: 13.97 - ETA: 1:35 - loss: 13.97 - ETA: 1:34 - loss: 14.02 - ETA: 1:33 - loss: 14.01 - ETA: 1:31 - loss: 13.99 - ETA: 1:30 - loss: 13.98 - ETA: 1:28 - loss: 13.96 - ETA: 1:27 - loss: 13.95 - ETA: 1:26 - loss: 13.94 - ETA: 1:23 - loss: 13.94 - ETA: 1:21 - loss: 13.93 - ETA: 1:20 - loss: 13.93 - ETA: 1:19 - loss: 13.92 - ETA: 1:17 - loss: 13.91 - ETA: 1:16 - loss: 13.91 - ETA: 1:15 - loss: 13.90 - ETA: 1:13 - loss: 13.91 - ETA: 1:10 - loss: 13.90 - ETA: 1:08 - loss: 13.89 - ETA: 1:06 - loss: 13.88 - ETA: 1:05 - loss: 13.89 - ETA: 1:03 - loss: 13.88 - ETA: 1:02 - loss: 13.87 - ETA: 1:00 - loss: 13.86 - ETA: 59s - loss: 13.8572 - ETA: 57s - loss: 13.863 - ETA: 55s - loss: 13.856 - ETA: 54s - loss: 13.841 - ETA: 52s - loss: 13.835 - ETA: 51s - loss: 13.853 - ETA: 49s - loss: 13.842 - ETA: 47s - loss: 13.840 - ETA: 46s - loss: 13.837 - ETA: 44s - loss: 13.828 - ETA: 42s - loss: 13.824 - ETA: 40s - loss: 13.817 - ETA: 39s - loss: 13.806 - ETA: 37s - loss: 13.793 - ETA: 35s - loss: 13.778 - ETA: 33s - loss: 13.812 - ETA: 31s - loss: 13.807 - ETA: 29s - loss: 13.799 - ETA: 28s - loss: 13.792 - ETA: 26s - loss: 13.786 - ETA: 24s - loss: 13.778 - ETA: 22s - loss: 13.787 - ETA: 20s - loss: 13.786 - ETA: 19s - loss: 13.795 - ETA: 17s - loss: 13.790 - ETA: 15s - loss: 13.796 - ETA: 13s - loss: 13.786 - ETA: 11s - loss: 13.783 - ETA: 9s - loss: 13.778 - ETA: 7s - loss: 13.77 - ETA: 5s - loss: 13.77 - ETA: 3s - loss: 13.77 - ETA: 1s - loss: 13.78 - 208s 2s/step - loss: 13.7737 - val_loss: 13.6663
#
# Epoch 00003: val_loss improved from 14.13930 to 13.66630, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-03_loss-13.7877_val_loss-13.6663.h5
# Epoch 4/120
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:10 - loss: 14.37 - ETA: 1:12 - loss: 13.79 - ETA: 1:12 - loss: 13.69 - ETA: 1:14 - loss: 13.77 - ETA: 1:17 - loss: 13.67 - ETA: 1:09 - loss: 13.88 - ETA: 1:52 - loss: 13.77 - ETA: 2:18 - loss: 13.70 - ETA: 2:36 - loss: 13.62 - ETA: 2:44 - loss: 13.59 - ETA: 2:49 - loss: 13.67 - ETA: 2:47 - loss: 13.62 - ETA: 2:49 - loss: 13.64 - ETA: 2:50 - loss: 13.60 - ETA: 2:51 - loss: 13.59 - ETA: 2:51 - loss: 13.57 - ETA: 2:51 - loss: 13.54 - ETA: 2:52 - loss: 13.60 - ETA: 2:50 - loss: 13.60 - ETA: 2:50 - loss: 13.64 - ETA: 2:48 - loss: 13.66 - ETA: 2:49 - loss: 13.66 - ETA: 2:48 - loss: 13.61 - ETA: 2:47 - loss: 13.58 - ETA: 2:46 - loss: 13.60 - ETA: 2:45 - loss: 13.60 - ETA: 2:43 - loss: 13.61 - ETA: 2:42 - loss: 13.59 - ETA: 2:40 - loss: 13.56 - ETA: 2:37 - loss: 13.62 - ETA: 2:35 - loss: 13.62 - ETA: 2:33 - loss: 13.61 - ETA: 2:31 - loss: 13.64 - ETA: 2:29 - loss: 13.62 - ETA: 2:27 - loss: 13.61 - ETA: 2:26 - loss: 13.59 - ETA: 2:23 - loss: 13.57 - ETA: 2:21 - loss: 13.55 - ETA: 2:19 - loss: 13.53 - ETA: 2:17 - loss: 13.52 - ETA: 2:15 - loss: 13.56 - ETA: 2:13 - loss: 13.55 - ETA: 2:11 - loss: 13.56 - ETA: 2:09 - loss: 13.55 - ETA: 2:07 - loss: 13.57 - ETA: 2:06 - loss: 13.62 - ETA: 2:04 - loss: 13.65 - ETA: 2:01 - loss: 13.63 - ETA: 1:59 - loss: 13.65 - ETA: 1:57 - loss: 13.64 - ETA: 1:55 - loss: 13.63 - ETA: 1:52 - loss: 13.62 - ETA: 1:50 - loss: 13.60 - ETA: 1:48 - loss: 13.59 - ETA: 1:46 - loss: 13.58 - ETA: 1:44 - loss: 13.59 - ETA: 1:42 - loss: 13.59 - ETA: 1:39 - loss: 13.58 - ETA: 1:37 - loss: 13.63 - ETA: 1:35 - loss: 13.62 - ETA: 1:33 - loss: 13.61 - ETA: 1:30 - loss: 13.60 - ETA: 1:28 - loss: 13.60 - ETA: 1:25 - loss: 13.59 - ETA: 1:23 - loss: 13.58 - ETA: 1:21 - loss: 13.57 - ETA: 1:18 - loss: 13.57 - ETA: 1:16 - loss: 13.56 - ETA: 1:14 - loss: 13.55 - ETA: 1:11 - loss: 13.55 - ETA: 1:09 - loss: 13.54 - ETA: 1:07 - loss: 13.53 - ETA: 1:05 - loss: 13.52 - ETA: 1:02 - loss: 13.53 - ETA: 1:00 - loss: 13.53 - ETA: 57s - loss: 13.5397 - ETA: 55s - loss: 13.532 - ETA: 53s - loss: 13.521 - ETA: 50s - loss: 13.515 - ETA: 48s - loss: 13.512 - ETA: 45s - loss: 13.510 - ETA: 43s - loss: 13.522 - ETA: 41s - loss: 13.517 - ETA: 38s - loss: 13.508 - ETA: 36s - loss: 13.507 - ETA: 33s - loss: 13.506 - ETA: 31s - loss: 13.508 - ETA: 29s - loss: 13.508 - ETA: 26s - loss: 13.516 - ETA: 24s - loss: 13.511 - ETA: 21s - loss: 13.505 - ETA: 19s - loss: 13.500 - ETA: 17s - loss: 13.514 - ETA: 14s - loss: 13.508 - ETA: 12s - loss: 13.512 - ETA: 9s - loss: 13.505 - ETA: 7s - loss: 13.50 - ETA: 4s - loss: 13.49 - ETA: 2s - loss: 13.49 - 266s 3s/step - loss: 13.4901 - val_loss: 13.3712
#
# Epoch 00004: val_loss improved from 13.66630 to 13.37120, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-04_loss-13.4774_val_loss-13.3712.h5
# Epoch 5/120
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:18 - loss: 12.56 - ETA: 1:22 - loss: 12.80 - ETA: 1:21 - loss: 13.17 - ETA: 1:20 - loss: 13.12 - ETA: 1:19 - loss: 13.37 - ETA: 1:18 - loss: 13.46 - ETA: 1:47 - loss: 13.46 - ETA: 1:36 - loss: 13.40 - ETA: 2:08 - loss: 13.33 - ETA: 2:26 - loss: 13.37 - ETA: 2:37 - loss: 13.32 - ETA: 2:42 - loss: 13.33 - ETA: 2:46 - loss: 13.29 - ETA: 2:50 - loss: 13.24 - ETA: 2:51 - loss: 13.22 - ETA: 2:52 - loss: 13.21 - ETA: 2:53 - loss: 13.19 - ETA: 2:53 - loss: 13.22 - ETA: 2:54 - loss: 13.21 - ETA: 2:53 - loss: 13.16 - ETA: 2:52 - loss: 13.14 - ETA: 2:49 - loss: 13.15 - ETA: 2:49 - loss: 13.25 - ETA: 2:46 - loss: 13.23 - ETA: 2:46 - loss: 13.23 - ETA: 2:45 - loss: 13.21 - ETA: 2:43 - loss: 13.25 - ETA: 2:41 - loss: 13.23 - ETA: 2:40 - loss: 13.21 - ETA: 2:38 - loss: 13.20 - ETA: 2:37 - loss: 13.19 - ETA: 2:35 - loss: 13.17 - ETA: 2:34 - loss: 13.15 - ETA: 2:32 - loss: 13.16 - ETA: 2:30 - loss: 13.15 - ETA: 2:28 - loss: 13.15 - ETA: 2:26 - loss: 13.14 - ETA: 2:24 - loss: 13.12 - ETA: 2:22 - loss: 13.14 - ETA: 2:19 - loss: 13.13 - ETA: 2:17 - loss: 13.13 - ETA: 2:15 - loss: 13.14 - ETA: 2:13 - loss: 13.13 - ETA: 2:11 - loss: 13.14 - ETA: 2:09 - loss: 13.16 - ETA: 2:07 - loss: 13.15 - ETA: 2:05 - loss: 13.17 - ETA: 2:03 - loss: 13.17 - ETA: 2:01 - loss: 13.16 - ETA: 1:59 - loss: 13.18 - ETA: 1:57 - loss: 13.17 - ETA: 1:54 - loss: 13.16 - ETA: 1:52 - loss: 13.18 - ETA: 1:50 - loss: 13.16 - ETA: 1:48 - loss: 13.16 - ETA: 1:46 - loss: 13.15 - ETA: 1:44 - loss: 13.15 - ETA: 1:41 - loss: 13.14 - ETA: 1:39 - loss: 13.16 - ETA: 1:37 - loss: 13.15 - ETA: 1:35 - loss: 13.15 - ETA: 1:33 - loss: 13.15 - ETA: 1:30 - loss: 13.14 - ETA: 1:28 - loss: 13.14 - ETA: 1:26 - loss: 13.13 - ETA: 1:24 - loss: 13.12 - ETA: 1:21 - loss: 13.11 - ETA: 1:19 - loss: 13.13 - ETA: 1:17 - loss: 13.14 - ETA: 1:14 - loss: 13.13 - ETA: 1:12 - loss: 13.13 - ETA: 1:09 - loss: 13.13 - ETA: 1:07 - loss: 13.13 - ETA: 1:04 - loss: 13.12 - ETA: 1:02 - loss: 13.11 - ETA: 59s - loss: 13.1293 - ETA: 57s - loss: 13.122 - ETA: 54s - loss: 13.118 - ETA: 52s - loss: 13.109 - ETA: 49s - loss: 13.106 - ETA: 47s - loss: 13.103 - ETA: 44s - loss: 13.098 - ETA: 42s - loss: 13.092 - ETA: 40s - loss: 13.097 - ETA: 37s - loss: 13.100 - ETA: 34s - loss: 13.101 - ETA: 32s - loss: 13.095 - ETA: 29s - loss: 13.083 - ETA: 27s - loss: 13.088 - ETA: 24s - loss: 13.082 - ETA: 22s - loss: 13.076 - ETA: 19s - loss: 13.070 - ETA: 17s - loss: 13.073 - ETA: 15s - loss: 13.063 - ETA: 12s - loss: 13.062 - ETA: 10s - loss: 13.054 - ETA: 7s - loss: 13.055 - ETA: 5s - loss: 13.06 - ETA: 2s - loss: 13.05 - 271s 3s/step - loss: 13.0537 - val_loss: 12.9251
#
# Epoch 00005: val_loss improved from 13.37120 to 12.92511, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-05_loss-13.0544_val_loss-12.9251.h5
# Epoch 6/120
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:20 - loss: 12.40 - ETA: 1:17 - loss: 12.56 - ETA: 1:17 - loss: 12.45 - ETA: 1:16 - loss: 12.57 - ETA: 1:17 - loss: 12.68 - ETA: 1:15 - loss: 12.62 - ETA: 1:57 - loss: 12.56 - ETA: 2:23 - loss: 12.54 - ETA: 2:41 - loss: 12.84 - ETA: 2:27 - loss: 33.55 - ETA: 2:33 - loss: 31.67 - ETA: 2:38 - loss: 30.14 - ETA: 2:43 - loss: 28.79 - ETA: 2:46 - loss: 27.64 - ETA: 2:48 - loss: 26.69 - ETA: 2:49 - loss: 25.81 - ETA: 2:49 - loss: 25.04 - ETA: 2:48 - loss: 24.35 - ETA: 2:48 - loss: 23.71 - ETA: 2:47 - loss: 23.17 - ETA: 2:48 - loss: 22.66 - ETA: 2:48 - loss: 22.24 - ETA: 2:47 - loss: 21.80 - ETA: 2:46 - loss: 21.41 - ETA: 2:45 - loss: 21.06 - ETA: 2:44 - loss: 20.78 - ETA: 2:43 - loss: 20.48 - ETA: 2:41 - loss: 20.21 - ETA: 2:39 - loss: 19.95 - ETA: 2:38 - loss: 19.70 - ETA: 2:37 - loss: 19.48 - ETA: 2:35 - loss: 19.26 - ETA: 2:33 - loss: 19.06 - ETA: 2:31 - loss: 18.87 - ETA: 2:29 - loss: 18.69 - ETA: 2:27 - loss: 18.56 - ETA: 2:25 - loss: 18.40 - ETA: 2:23 - loss: 18.24 - ETA: 2:22 - loss: 18.09 - ETA: 2:20 - loss: 18.03 - ETA: 2:17 - loss: 17.89 - ETA: 2:15 - loss: 17.77 - ETA: 2:13 - loss: 17.64 - ETA: 2:11 - loss: 17.51 - ETA: 2:09 - loss: 17.40 - ETA: 2:07 - loss: 17.31 - ETA: 2:05 - loss: 17.22 - ETA: 2:02 - loss: 17.12 - ETA: 2:00 - loss: 17.03 - ETA: 1:57 - loss: 16.94 - ETA: 1:55 - loss: 16.85 - ETA: 1:53 - loss: 16.78 - ETA: 1:51 - loss: 16.73 - ETA: 1:48 - loss: 16.65 - ETA: 1:46 - loss: 16.57 - ETA: 1:44 - loss: 16.49 - ETA: 1:42 - loss: 16.41 - ETA: 1:40 - loss: 16.37 - ETA: 1:38 - loss: 16.30 - ETA: 1:35 - loss: 16.23 - ETA: 1:33 - loss: 16.17 - ETA: 1:31 - loss: 16.10 - ETA: 1:28 - loss: 16.04 - ETA: 1:26 - loss: 15.98 - ETA: 1:24 - loss: 15.92 - ETA: 1:21 - loss: 15.87 - ETA: 1:19 - loss: 15.81 - ETA: 1:17 - loss: 15.76 - ETA: 1:15 - loss: 15.73 - ETA: 1:12 - loss: 15.68 - ETA: 1:10 - loss: 15.63 - ETA: 1:07 - loss: 15.59 - ETA: 1:05 - loss: 15.54 - ETA: 1:03 - loss: 15.49 - ETA: 1:00 - loss: 15.47 - ETA: 58s - loss: 15.4468 - ETA: 56s - loss: 15.419 - ETA: 53s - loss: 15.376 - ETA: 51s - loss: 15.351 - ETA: 48s - loss: 15.312 - ETA: 46s - loss: 15.274 - ETA: 44s - loss: 15.268 - ETA: 41s - loss: 15.240 - ETA: 39s - loss: 15.209 - ETA: 36s - loss: 15.174 - ETA: 34s - loss: 15.140 - ETA: 31s - loss: 15.104 - ETA: 29s - loss: 15.071 - ETA: 27s - loss: 15.053 - ETA: 24s - loss: 15.023 - ETA: 22s - loss: 14.990 - ETA: 19s - loss: 14.984 - ETA: 17s - loss: 14.955 - ETA: 14s - loss: 14.924 - ETA: 12s - loss: 14.902 - ETA: 9s - loss: 14.888 - ETA: 7s - loss: 14.85 - ETA: 4s - loss: 14.82 - ETA: 2s - loss: 14.80 - 267s 3s/step - loss: 14.7700 - val_loss: 12.7101
#
# Epoch 00006: val_loss improved from 12.92511 to 12.71014, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-06_loss-12.9767_val_loss-12.7101.h5
# Epoch 7/120
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:14 - loss: 12.48 - ETA: 1:14 - loss: 12.05 - ETA: 1:14 - loss: 12.15 - ETA: 1:13 - loss: 12.21 - ETA: 1:14 - loss: 12.12 - ETA: 1:13 - loss: 12.38 - ETA: 1:48 - loss: 12.53 - ETA: 2:20 - loss: 12.50 - ETA: 2:46 - loss: 12.69 - ETA: 2:50 - loss: 12.62 - ETA: 2:56 - loss: 12.71 - ETA: 2:41 - loss: 12.61 - ETA: 2:46 - loss: 12.54 - ETA: 2:48 - loss: 12.51 - ETA: 2:50 - loss: 12.47 - ETA: 2:52 - loss: 12.48 - ETA: 2:52 - loss: 12.44 - ETA: 2:52 - loss: 12.42 - ETA: 2:51 - loss: 12.45 - ETA: 2:51 - loss: 12.57 - ETA: 2:50 - loss: 12.58 - ETA: 2:50 - loss: 12.56 - ETA: 2:48 - loss: 12.52 - ETA: 2:47 - loss: 12.49 - ETA: 2:45 - loss: 12.54 - ETA: 2:45 - loss: 12.52 - ETA: 2:43 - loss: 12.50 - ETA: 2:43 - loss: 12.48 - ETA: 2:41 - loss: 12.47 - ETA: 2:40 - loss: 12.45 - ETA: 2:38 - loss: 12.48 - ETA: 2:37 - loss: 12.47 - ETA: 2:35 - loss: 12.46 - ETA: 2:34 - loss: 12.47 - ETA: 2:32 - loss: 12.46 - ETA: 2:30 - loss: 12.46 - ETA: 2:28 - loss: 12.54 - ETA: 2:26 - loss: 12.53 - ETA: 2:24 - loss: 12.54 - ETA: 2:23 - loss: 12.56 - ETA: 2:21 - loss: 12.55 - ETA: 2:18 - loss: 12.54 - ETA: 2:16 - loss: 12.56 - ETA: 2:14 - loss: 12.55 - ETA: 2:11 - loss: 12.54 - ETA: 2:09 - loss: 12.53 - ETA: 2:07 - loss: 12.53 - ETA: 2:05 - loss: 12.52 - ETA: 2:02 - loss: 12.51 - ETA: 2:00 - loss: 12.51 - ETA: 1:58 - loss: 12.52 - ETA: 1:56 - loss: 12.52 - ETA: 1:53 - loss: 12.51 - ETA: 1:51 - loss: 12.51 - ETA: 1:49 - loss: 12.50 - ETA: 1:46 - loss: 12.57 - ETA: 1:44 - loss: 12.57 - ETA: 1:41 - loss: 12.55 - ETA: 1:39 - loss: 12.54 - ETA: 1:36 - loss: 12.54 - ETA: 1:34 - loss: 12.54 - ETA: 1:32 - loss: 12.53 - ETA: 1:29 - loss: 12.52 - ETA: 1:27 - loss: 12.51 - ETA: 1:24 - loss: 12.51 - ETA: 1:22 - loss: 12.53 - ETA: 1:20 - loss: 12.53 - ETA: 1:17 - loss: 12.53 - ETA: 1:15 - loss: 12.53 - ETA: 1:13 - loss: 12.53 - ETA: 1:10 - loss: 12.53 - ETA: 1:08 - loss: 12.52 - ETA: 1:06 - loss: 12.51 - ETA: 1:03 - loss: 12.50 - ETA: 1:01 - loss: 12.52 - ETA: 58s - loss: 12.5207 - ETA: 56s - loss: 12.509 - ETA: 53s - loss: 12.504 - ETA: 51s - loss: 12.495 - ETA: 49s - loss: 12.488 - ETA: 46s - loss: 12.486 - ETA: 44s - loss: 12.488 - ETA: 41s - loss: 12.482 - ETA: 39s - loss: 12.488 - ETA: 36s - loss: 12.483 - ETA: 34s - loss: 12.478 - ETA: 31s - loss: 12.482 - ETA: 29s - loss: 12.477 - ETA: 27s - loss: 12.490 - ETA: 24s - loss: 12.480 - ETA: 22s - loss: 12.479 - ETA: 19s - loss: 12.472 - ETA: 17s - loss: 12.466 - ETA: 14s - loss: 12.463 - ETA: 12s - loss: 12.470 - ETA: 9s - loss: 12.463 - ETA: 7s - loss: 12.45 - ETA: 4s - loss: 12.46 - ETA: 2s - loss: 12.45 - 266s 3s/step - loss: 12.4496 - val_loss: 12.4104
#
# Epoch 00007: val_loss improved from 12.71014 to 12.41044, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-07_loss-12.4583_val_loss-12.4104.h5
# Epoch 8/120
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:12 - loss: 11.95 - ETA: 1:16 - loss: 11.94 - ETA: 1:17 - loss: 11.81 - ETA: 1:16 - loss: 11.87 - ETA: 1:15 - loss: 12.00 - ETA: 1:15 - loss: 12.20 - ETA: 1:39 - loss: 12.17 - ETA: 2:08 - loss: 12.17 - ETA: 2:30 - loss: 12.14 - ETA: 2:43 - loss: 12.17 - ETA: 2:49 - loss: 12.21 - ETA: 2:52 - loss: 12.18 - ETA: 2:53 - loss: 12.15 - ETA: 2:40 - loss: 12.06 - ETA: 2:43 - loss: 12.06 - ETA: 2:43 - loss: 12.06 - ETA: 2:44 - loss: 12.10 - ETA: 2:44 - loss: 12.08 - ETA: 2:44 - loss: 12.08 - ETA: 2:44 - loss: 12.06 - ETA: 2:43 - loss: 12.03 - ETA: 2:43 - loss: 12.04 - ETA: 2:43 - loss: 12.02 - ETA: 2:42 - loss: 12.03 - ETA: 2:42 - loss: 12.02 - ETA: 2:41 - loss: 12.00 - ETA: 2:41 - loss: 12.06 - ETA: 2:40 - loss: 12.07 - ETA: 2:38 - loss: 12.05 - ETA: 2:37 - loss: 12.04 - ETA: 2:36 - loss: 12.05 - ETA: 2:34 - loss: 12.04 - ETA: 2:33 - loss: 12.07 - ETA: 2:31 - loss: 12.06 - ETA: 2:29 - loss: 12.06 - ETA: 2:27 - loss: 12.07 - ETA: 2:25 - loss: 12.08 - ETA: 2:23 - loss: 12.08 - ETA: 2:21 - loss: 12.09 - ETA: 2:19 - loss: 12.12 - ETA: 2:17 - loss: 12.12 - ETA: 2:15 - loss: 12.10 - ETA: 2:13 - loss: 12.09 - ETA: 2:11 - loss: 12.08 - ETA: 2:09 - loss: 12.07 - ETA: 2:07 - loss: 12.07 - ETA: 2:05 - loss: 12.06 - ETA: 2:03 - loss: 12.06 - ETA: 2:01 - loss: 12.06 - ETA: 1:58 - loss: 12.05 - ETA: 1:56 - loss: 12.04 - ETA: 1:55 - loss: 12.09 - ETA: 1:53 - loss: 12.10 - ETA: 1:51 - loss: 12.11 - ETA: 1:49 - loss: 12.13 - ETA: 1:46 - loss: 12.11 - ETA: 1:44 - loss: 12.14 - ETA: 1:42 - loss: 12.14 - ETA: 1:40 - loss: 12.13 - ETA: 1:38 - loss: 12.12 - ETA: 1:36 - loss: 12.12 - ETA: 1:33 - loss: 12.11 - ETA: 1:31 - loss: 12.10 - ETA: 1:28 - loss: 12.10 - ETA: 1:26 - loss: 12.09 - ETA: 1:24 - loss: 12.09 - ETA: 1:21 - loss: 12.08 - ETA: 1:19 - loss: 12.08 - ETA: 1:16 - loss: 12.07 - ETA: 1:14 - loss: 12.06 - ETA: 1:12 - loss: 12.06 - ETA: 1:09 - loss: 12.05 - ETA: 1:08 - loss: 12.05 - ETA: 1:05 - loss: 12.04 - ETA: 1:03 - loss: 12.04 - ETA: 1:01 - loss: 12.04 - ETA: 59s - loss: 12.0332 - ETA: 56s - loss: 12.031 - ETA: 54s - loss: 12.029 - ETA: 51s - loss: 12.027 - ETA: 49s - loss: 12.022 - ETA: 46s - loss: 12.037 - ETA: 43s - loss: 12.032 - ETA: 41s - loss: 12.029 - ETA: 38s - loss: 12.020 - ETA: 36s - loss: 12.022 - ETA: 33s - loss: 12.016 - ETA: 31s - loss: 12.010 - ETA: 28s - loss: 12.015 - ETA: 25s - loss: 12.010 - ETA: 23s - loss: 12.035 - ETA: 20s - loss: 12.031 - ETA: 18s - loss: 12.049 - ETA: 15s - loss: 12.048 - ETA: 13s - loss: 12.044 - ETA: 10s - loss: 12.044 - ETA: 7s - loss: 12.048 - ETA: 5s - loss: 12.04 - ETA: 2s - loss: 12.04 - 287s 3s/step - loss: 12.0511 - val_loss: 12.3392
#
# Epoch 00008: val_loss improved from 12.41044 to 12.33916, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-08_loss-12.0618_val_loss-12.3392.h5
# Epoch 9/120
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:16 - loss: 11.95 - ETA: 1:17 - loss: 11.99 - ETA: 1:17 - loss: 11.74 - ETA: 1:19 - loss: 11.78 - ETA: 1:17 - loss: 11.85 - ETA: 1:17 - loss: 11.87 - ETA: 1:41 - loss: 11.88 - ETA: 2:19 - loss: 11.85 - ETA: 2:46 - loss: 11.97 - ETA: 3:00 - loss: 12.44 - ETA: 3:07 - loss: 12.38 - ETA: 3:15 - loss: 12.53 - ETA: 3:18 - loss: 12.46 - ETA: 3:25 - loss: 12.55 - ETA: 3:27 - loss: 12.50 - ETA: 3:13 - loss: 12.44 - ETA: 3:15 - loss: 12.41 - ETA: 3:16 - loss: 12.39 - ETA: 3:18 - loss: 12.35 - ETA: 3:19 - loss: 12.31 - ETA: 3:19 - loss: 12.27 - ETA: 3:20 - loss: 12.28 - ETA: 3:21 - loss: 12.24 - ETA: 3:20 - loss: 12.20 - ETA: 3:19 - loss: 12.18 - ETA: 3:16 - loss: 12.15 - ETA: 3:15 - loss: 12.12 - ETA: 3:14 - loss: 12.09 - ETA: 3:12 - loss: 12.08 - ETA: 3:11 - loss: 12.09 - ETA: 3:10 - loss: 12.09 - ETA: 3:07 - loss: 12.08 - ETA: 3:04 - loss: 12.06 - ETA: 3:01 - loss: 12.04 - ETA: 2:59 - loss: 12.07 - ETA: 2:56 - loss: 12.04 - ETA: 2:53 - loss: 12.04 - ETA: 2:50 - loss: 12.04 - ETA: 2:48 - loss: 12.08 - ETA: 2:45 - loss: 12.07 - ETA: 2:42 - loss: 12.06 - ETA: 2:39 - loss: 12.05 - ETA: 2:37 - loss: 12.03 - ETA: 2:34 - loss: 12.02 - ETA: 2:32 - loss: 12.08 - ETA: 2:29 - loss: 12.07 - ETA: 2:26 - loss: 12.09 - ETA: 2:23 - loss: 12.08 - ETA: 2:19 - loss: 12.07 - ETA: 2:15 - loss: 12.06 - ETA: 2:10 - loss: 12.07 - ETA: 2:08 - loss: 12.05 - ETA: 2:05 - loss: 12.06 - ETA: 2:02 - loss: 12.05 - ETA: 2:00 - loss: 12.04 - ETA: 1:57 - loss: 12.08 - ETA: 1:54 - loss: 12.08 - ETA: 1:51 - loss: 12.06 - ETA: 1:49 - loss: 12.08 - ETA: 1:46 - loss: 12.09 - ETA: 1:44 - loss: 12.10 - ETA: 1:41 - loss: 12.09 - ETA: 1:38 - loss: 12.07 - ETA: 1:36 - loss: 12.07 - ETA: 1:33 - loss: 12.08 - ETA: 1:31 - loss: 12.07 - ETA: 1:28 - loss: 12.07 - ETA: 1:26 - loss: 12.09 - ETA: 1:23 - loss: 12.08 - ETA: 1:20 - loss: 12.07 - ETA: 1:18 - loss: 12.08 - ETA: 1:15 - loss: 12.08 - ETA: 1:12 - loss: 12.07 - ETA: 1:10 - loss: 12.07 - ETA: 1:07 - loss: 12.07 - ETA: 1:05 - loss: 12.06 - ETA: 1:02 - loss: 12.05 - ETA: 1:00 - loss: 12.05 - ETA: 57s - loss: 12.0459 - ETA: 54s - loss: 12.052 - ETA: 52s - loss: 12.047 - ETA: 49s - loss: 12.039 - ETA: 46s - loss: 12.049 - ETA: 43s - loss: 12.041 - ETA: 41s - loss: 12.045 - ETA: 38s - loss: 12.039 - ETA: 35s - loss: 12.033 - ETA: 32s - loss: 12.024 - ETA: 30s - loss: 12.014 - ETA: 27s - loss: 12.005 - ETA: 24s - loss: 11.999 - ETA: 21s - loss: 11.995 - ETA: 19s - loss: 11.990 - ETA: 16s - loss: 12.003 - ETA: 13s - loss: 12.000 - ETA: 10s - loss: 11.995 - ETA: 8s - loss: 11.991 - ETA: 5s - loss: 11.99 - ETA: 2s - loss: 11.99 - 294s 3s/step - loss: 11.9933 - val_loss: 11.9706
#
# Epoch 00009: val_loss improved from 12.33916 to 11.97057, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-09_loss-11.9969_val_loss-11.9706.h5
# Epoch 10/120
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:19 - loss: 12.33 - ETA: 1:22 - loss: 12.15 - ETA: 1:18 - loss: 11.77 - ETA: 1:19 - loss: 11.69 - ETA: 1:17 - loss: 11.72 - ETA: 1:15 - loss: 11.66 - ETA: 1:44 - loss: 11.64 - ETA: 2:15 - loss: 11.58 - ETA: 2:38 - loss: 11.64 - ETA: 2:47 - loss: 11.66 - ETA: 2:52 - loss: 11.64 - ETA: 2:55 - loss: 11.61 - ETA: 2:58 - loss: 11.59 - ETA: 3:02 - loss: 11.76 - ETA: 3:04 - loss: 11.71 - ETA: 3:07 - loss: 11.71 - ETA: 3:07 - loss: 11.72 - ETA: 2:56 - loss: 11.70 - ETA: 2:56 - loss: 11.70 - ETA: 2:55 - loss: 11.77 - ETA: 2:55 - loss: 11.76 - ETA: 2:54 - loss: 11.75 - ETA: 2:54 - loss: 11.76 - ETA: 2:53 - loss: 11.75 - ETA: 2:50 - loss: 11.74 - ETA: 2:50 - loss: 11.73 - ETA: 2:48 - loss: 11.72 - ETA: 2:47 - loss: 11.72 - ETA: 2:46 - loss: 11.73 - ETA: 2:45 - loss: 11.72 - ETA: 2:44 - loss: 11.71 - ETA: 2:42 - loss: 11.70 - ETA: 2:41 - loss: 11.73 - ETA: 2:39 - loss: 11.75 - ETA: 2:37 - loss: 11.75 - ETA: 2:34 - loss: 11.76 - ETA: 2:32 - loss: 11.74 - ETA: 2:30 - loss: 11.72 - ETA: 2:28 - loss: 11.73 - ETA: 2:26 - loss: 11.71 - ETA: 2:24 - loss: 11.71 - ETA: 2:21 - loss: 11.71 - ETA: 2:19 - loss: 11.72 - ETA: 2:17 - loss: 11.71 - ETA: 2:15 - loss: 11.70 - ETA: 2:13 - loss: 11.70 - ETA: 2:11 - loss: 11.70 - ETA: 2:09 - loss: 11.70 - ETA: 2:07 - loss: 11.69 - ETA: 2:05 - loss: 11.69 - ETA: 2:03 - loss: 11.71 - ETA: 2:01 - loss: 11.71 - ETA: 2:00 - loss: 11.76 - ETA: 1:58 - loss: 11.76 - ETA: 1:55 - loss: 11.75 - ETA: 1:53 - loss: 11.75 - ETA: 1:51 - loss: 11.74 - ETA: 1:48 - loss: 11.74 - ETA: 1:46 - loss: 11.76 - ETA: 1:44 - loss: 11.76 - ETA: 1:42 - loss: 11.75 - ETA: 1:40 - loss: 11.74 - ETA: 1:38 - loss: 11.75 - ETA: 1:35 - loss: 11.74 - ETA: 1:33 - loss: 11.76 - ETA: 1:31 - loss: 11.75 - ETA: 1:28 - loss: 11.74 - ETA: 1:25 - loss: 11.74 - ETA: 1:23 - loss: 11.74 - ETA: 1:20 - loss: 11.73 - ETA: 1:18 - loss: 11.73 - ETA: 1:15 - loss: 11.72 - ETA: 1:13 - loss: 11.71 - ETA: 1:10 - loss: 11.71 - ETA: 1:07 - loss: 11.70 - ETA: 1:05 - loss: 11.71 - ETA: 1:03 - loss: 11.71 - ETA: 1:00 - loss: 11.70 - ETA: 57s - loss: 11.6947 - ETA: 55s - loss: 11.704 - ETA: 52s - loss: 11.696 - ETA: 49s - loss: 11.691 - ETA: 47s - loss: 11.708 - ETA: 44s - loss: 11.713 - ETA: 41s - loss: 11.724 - ETA: 38s - loss: 11.723 - ETA: 35s - loss: 11.722 - ETA: 33s - loss: 11.721 - ETA: 30s - loss: 11.718 - ETA: 27s - loss: 11.711 - ETA: 24s - loss: 11.707 - ETA: 22s - loss: 11.705 - ETA: 19s - loss: 11.706 - ETA: 16s - loss: 11.707 - ETA: 13s - loss: 11.706 - ETA: 11s - loss: 11.734 - ETA: 8s - loss: 11.725 - ETA: 5s - loss: 11.73 - ETA: 2s - loss: 11.72 - 295s 3s/step - loss: 11.7231 - val_loss: 11.7525
#
# Epoch 00010: val_loss improved from 11.97057 to 11.75247, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-10_loss-11.7271_val_loss-11.7525.h5
# Epoch 11/120
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:19 - loss: 11.43 - ETA: 1:18 - loss: 11.35 - ETA: 1:18 - loss: 11.37 - ETA: 1:19 - loss: 11.31 - ETA: 1:19 - loss: 11.41 - ETA: 1:16 - loss: 11.38 - ETA: 1:47 - loss: 11.34 - ETA: 2:21 - loss: 11.61 - ETA: 2:48 - loss: 11.64 - ETA: 2:52 - loss: 11.58 - ETA: 2:57 - loss: 11.54 - ETA: 2:58 - loss: 11.52 - ETA: 2:59 - loss: 11.48 - ETA: 3:01 - loss: 11.46 - ETA: 3:04 - loss: 11.59 - ETA: 3:05 - loss: 11.63 - ETA: 3:06 - loss: 11.65 - ETA: 3:08 - loss: 11.64 - ETA: 3:09 - loss: 11.63 - ETA: 2:58 - loss: 11.59 - ETA: 2:59 - loss: 11.58 - ETA: 2:59 - loss: 11.56 - ETA: 2:59 - loss: 11.57 - ETA: 3:00 - loss: 11.56 - ETA: 3:01 - loss: 11.54 - ETA: 3:01 - loss: 11.52 - ETA: 3:03 - loss: 11.52 - ETA: 3:03 - loss: 11.56 - ETA: 3:03 - loss: 11.55 - ETA: 3:03 - loss: 11.54 - ETA: 3:01 - loss: 11.51 - ETA: 3:00 - loss: 11.49 - ETA: 2:59 - loss: 11.48 - ETA: 2:57 - loss: 11.47 - ETA: 2:55 - loss: 11.47 - ETA: 2:54 - loss: 11.46 - ETA: 2:52 - loss: 11.48 - ETA: 2:50 - loss: 11.46 - ETA: 2:48 - loss: 11.46 - ETA: 2:45 - loss: 11.45 - ETA: 2:43 - loss: 11.44 - ETA: 2:41 - loss: 11.44 - ETA: 2:38 - loss: 11.43 - ETA: 2:35 - loss: 11.43 - ETA: 2:33 - loss: 11.44 - ETA: 2:30 - loss: 11.43 - ETA: 2:26 - loss: 11.42 - ETA: 2:24 - loss: 11.41 - ETA: 2:21 - loss: 11.40 - ETA: 2:18 - loss: 11.41 - ETA: 2:15 - loss: 11.40 - ETA: 2:12 - loss: 11.44 - ETA: 2:09 - loss: 11.44 - ETA: 2:06 - loss: 11.45 - ETA: 2:03 - loss: 11.44 - ETA: 2:00 - loss: 11.44 - ETA: 1:57 - loss: 11.43 - ETA: 1:54 - loss: 11.46 - ETA: 1:52 - loss: 11.48 - ETA: 1:49 - loss: 11.48 - ETA: 1:46 - loss: 11.50 - ETA: 1:44 - loss: 11.49 - ETA: 1:41 - loss: 11.48 - ETA: 1:39 - loss: 11.48 - ETA: 1:36 - loss: 11.49 - ETA: 1:34 - loss: 11.49 - ETA: 1:31 - loss: 11.50 - ETA: 1:29 - loss: 11.50 - ETA: 1:27 - loss: 11.50 - ETA: 1:24 - loss: 11.50 - ETA: 1:21 - loss: 11.50 - ETA: 1:18 - loss: 11.52 - ETA: 1:16 - loss: 11.52 - ETA: 1:13 - loss: 11.52 - ETA: 1:10 - loss: 11.53 - ETA: 1:07 - loss: 11.52 - ETA: 1:04 - loss: 11.54 - ETA: 1:02 - loss: 11.54 - ETA: 59s - loss: 11.5467 - ETA: 56s - loss: 11.537 - ETA: 53s - loss: 11.531 - ETA: 51s - loss: 11.523 - ETA: 48s - loss: 11.518 - ETA: 45s - loss: 11.510 - ETA: 42s - loss: 11.504 - ETA: 40s - loss: 11.516 - ETA: 37s - loss: 11.518 - ETA: 34s - loss: 11.516 - ETA: 31s - loss: 11.523 - ETA: 28s - loss: 11.527 - ETA: 25s - loss: 11.519 - ETA: 23s - loss: 11.517 - ETA: 20s - loss: 11.513 - ETA: 17s - loss: 11.509 - ETA: 14s - loss: 11.503 - ETA: 11s - loss: 11.508 - ETA: 8s - loss: 11.524 - ETA: 5s - loss: 11.54 - ETA: 2s - loss: 11.53 - 313s 3s/step - loss: 11.5321 - val_loss: 11.5714
#
# Epoch 00011: val_loss improved from 11.75247 to 11.57143, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-11_loss-11.5377_val_loss-11.5714.h5
# Epoch 12/120
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:15 - loss: 12.52 - ETA: 1:27 - loss: 11.75 - ETA: 1:19 - loss: 11.67 - ETA: 1:18 - loss: 11.49 - ETA: 1:17 - loss: 11.31 - ETA: 1:16 - loss: 11.81 - ETA: 1:36 - loss: 11.70 - ETA: 2:09 - loss: 11.64 - ETA: 2:33 - loss: 11.62 - ETA: 2:50 - loss: 11.58 - ETA: 3:03 - loss: 11.53 - ETA: 3:12 - loss: 11.47 - ETA: 3:15 - loss: 11.46 - ETA: 3:14 - loss: 11.41 - ETA: 3:18 - loss: 11.40 - ETA: 3:18 - loss: 11.39 - ETA: 3:17 - loss: 11.39 - ETA: 3:14 - loss: 11.37 - ETA: 3:12 - loss: 11.38 - ETA: 3:11 - loss: 11.37 - ETA: 3:11 - loss: 11.35 - ETA: 3:01 - loss: 11.34 - ETA: 3:00 - loss: 11.32 - ETA: 2:59 - loss: 11.30 - ETA: 3:00 - loss: 11.30 - ETA: 3:03 - loss: 11.28 - ETA: 3:05 - loss: 11.28 - ETA: 3:08 - loss: 11.27 - ETA: 3:10 - loss: 11.26 - ETA: 3:13 - loss: 11.25 - ETA: 3:13 - loss: 11.25 - ETA: 3:14 - loss: 11.25 - ETA: 3:14 - loss: 11.24 - ETA: 3:13 - loss: 11.23 - ETA: 3:12 - loss: 11.29 - ETA: 3:13 - loss: 11.28 - ETA: 3:13 - loss: 11.28 - ETA: 3:11 - loss: 11.28 - ETA: 3:11 - loss: 11.27 - ETA: 3:10 - loss: 11.30 - ETA: 3:08 - loss: 11.30 - ETA: 3:05 - loss: 11.28 - ETA: 3:03 - loss: 11.27 - ETA: 3:00 - loss: 11.28 - ETA: 2:57 - loss: 11.27 - ETA: 2:54 - loss: 11.26 - ETA: 2:51 - loss: 11.25 - ETA: 2:49 - loss: 11.24 - ETA: 2:46 - loss: 11.27 - ETA: 2:42 - loss: 11.26 - ETA: 2:39 - loss: 11.28 - ETA: 2:36 - loss: 11.28 - ETA: 2:32 - loss: 11.27 - ETA: 2:29 - loss: 11.27 - ETA: 2:26 - loss: 11.28 - ETA: 2:22 - loss: 11.26 - ETA: 2:19 - loss: 11.26 - ETA: 2:16 - loss: 11.29 - ETA: 2:12 - loss: 11.28 - ETA: 2:09 - loss: 11.34 - ETA: 2:06 - loss: 11.34 - ETA: 2:03 - loss: 11.33 - ETA: 2:00 - loss: 11.33 - ETA: 1:56 - loss: 11.33 - ETA: 1:53 - loss: 11.32 - ETA: 1:49 - loss: 11.32 - ETA: 1:46 - loss: 11.31 - ETA: 1:43 - loss: 11.32 - ETA: 1:39 - loss: 11.32 - ETA: 1:36 - loss: 11.32 - ETA: 1:33 - loss: 11.32 - ETA: 1:29 - loss: 11.31 - ETA: 1:26 - loss: 11.31 - ETA: 1:23 - loss: 11.33 - ETA: 1:19 - loss: 11.32 - ETA: 1:16 - loss: 11.31 - ETA: 1:13 - loss: 11.30 - ETA: 1:10 - loss: 11.31 - ETA: 1:07 - loss: 11.31 - ETA: 1:04 - loss: 11.31 - ETA: 1:00 - loss: 11.30 - ETA: 57s - loss: 11.2941 - ETA: 54s - loss: 11.295 - ETA: 51s - loss: 11.286 - ETA: 48s - loss: 11.282 - ETA: 44s - loss: 11.276 - ETA: 41s - loss: 11.268 - ETA: 38s - loss: 11.267 - ETA: 35s - loss: 11.261 - ETA: 32s - loss: 11.279 - ETA: 28s - loss: 11.280 - ETA: 25s - loss: 11.289 - ETA: 22s - loss: 11.295 - ETA: 19s - loss: 11.288 - ETA: 16s - loss: 11.289 - ETA: 12s - loss: 11.283 - ETA: 9s - loss: 11.282 - ETA: 6s - loss: 11.29 - ETA: 3s - loss: 11.29 - 343s 3s/step - loss: 11.2929 - val_loss: 11.3779
#
# Epoch 00012: val_loss improved from 11.57143 to 11.37788, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-12_loss-11.2946_val_loss-11.3779.h5
# Epoch 13/120
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:30 - loss: 10.74 - ETA: 1:22 - loss: 10.97 - ETA: 1:19 - loss: 10.92 - ETA: 1:16 - loss: 10.97 - ETA: 1:16 - loss: 10.94 - ETA: 1:17 - loss: 10.90 - ETA: 1:15 - loss: 10.86 - ETA: 1:52 - loss: 10.89 - ETA: 2:17 - loss: 10.87 - ETA: 2:43 - loss: 10.87 - ETA: 2:56 - loss: 10.85 - ETA: 3:01 - loss: 10.91 - ETA: 3:04 - loss: 10.91 - ETA: 3:03 - loss: 10.92 - ETA: 3:06 - loss: 10.89 - ETA: 3:05 - loss: 10.88 - ETA: 3:08 - loss: 10.88 - ETA: 3:08 - loss: 10.87 - ETA: 3:11 - loss: 10.87 - ETA: 3:11 - loss: 10.87 - ETA: 3:12 - loss: 10.90 - ETA: 3:11 - loss: 10.90 - ETA: 3:09 - loss: 10.94 - ETA: 3:00 - loss: 10.94 - ETA: 3:00 - loss: 10.93 - ETA: 3:00 - loss: 10.93 - ETA: 2:57 - loss: 10.92 - ETA: 2:55 - loss: 10.93 - ETA: 2:52 - loss: 10.93 - ETA: 2:50 - loss: 10.93 - ETA: 2:50 - loss: 10.95 - ETA: 2:48 - loss: 10.93 - ETA: 2:46 - loss: 10.92 - ETA: 2:45 - loss: 10.99 - ETA: 2:43 - loss: 10.99 - ETA: 2:42 - loss: 11.03 - ETA: 2:41 - loss: 11.02 - ETA: 2:39 - loss: 11.02 - ETA: 2:37 - loss: 11.01 - ETA: 2:35 - loss: 11.03 - ETA: 2:32 - loss: 11.03 - ETA: 2:30 - loss: 11.04 - ETA: 2:28 - loss: 11.10 - ETA: 2:25 - loss: 11.12 - ETA: 2:24 - loss: 11.12 - ETA: 2:21 - loss: 11.11 - ETA: 2:19 - loss: 11.11 - ETA: 2:16 - loss: 11.12 - ETA: 2:13 - loss: 11.11 - ETA: 2:12 - loss: 11.11 - ETA: 2:09 - loss: 11.10 - ETA: 2:07 - loss: 11.09 - ETA: 2:05 - loss: 11.09 - ETA: 2:02 - loss: 11.08 - ETA: 2:00 - loss: 11.08 - ETA: 1:58 - loss: 11.08 - ETA: 1:57 - loss: 11.09 - ETA: 1:54 - loss: 11.08 - ETA: 1:52 - loss: 11.09 - ETA: 1:49 - loss: 11.09 - ETA: 1:46 - loss: 11.08 - ETA: 1:44 - loss: 11.09 - ETA: 1:42 - loss: 11.09 - ETA: 1:40 - loss: 11.09 - ETA: 1:37 - loss: 11.09 - ETA: 1:34 - loss: 11.09 - ETA: 1:32 - loss: 11.08 - ETA: 1:29 - loss: 11.08 - ETA: 1:26 - loss: 11.07 - ETA: 1:23 - loss: 11.09 - ETA: 1:20 - loss: 11.08 - ETA: 1:17 - loss: 11.08 - ETA: 1:15 - loss: 11.08 - ETA: 1:12 - loss: 11.08 - ETA: 1:10 - loss: 11.08 - ETA: 1:07 - loss: 11.07 - ETA: 1:05 - loss: 11.07 - ETA: 1:02 - loss: 11.06 - ETA: 59s - loss: 11.0634 - ETA: 56s - loss: 11.061 - ETA: 53s - loss: 11.072 - ETA: 50s - loss: 11.065 - ETA: 48s - loss: 11.061 - ETA: 45s - loss: 11.057 - ETA: 42s - loss: 11.051 - ETA: 39s - loss: 11.049 - ETA: 36s - loss: 11.043 - ETA: 34s - loss: 11.048 - ETA: 31s - loss: 11.045 - ETA: 28s - loss: 11.051 - ETA: 25s - loss: 11.044 - ETA: 22s - loss: 11.040 - ETA: 19s - loss: 11.038 - ETA: 17s - loss: 11.039 - ETA: 14s - loss: 11.037 - ETA: 11s - loss: 11.051 - ETA: 8s - loss: 11.053 - ETA: 5s - loss: 11.05 - ETA: 2s - loss: 11.04 - 308s 3s/step - loss: 11.0421 - val_loss: 11.1696
#
# Epoch 00013: val_loss improved from 11.37788 to 11.16955, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-13_loss-11.0430_val_loss-11.1696.h5
# Epoch 14/120
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:32 - loss: 11.24 - ETA: 1:31 - loss: 10.91 - ETA: 1:26 - loss: 11.09 - ETA: 1:26 - loss: 11.07 - ETA: 1:24 - loss: 11.06 - ETA: 1:22 - loss: 11.06 - ETA: 1:46 - loss: 10.99 - ETA: 2:19 - loss: 11.42 - ETA: 2:43 - loss: 11.35 - ETA: 2:54 - loss: 11.38 - ETA: 2:57 - loss: 11.27 - ETA: 3:05 - loss: 11.17 - ETA: 3:17 - loss: 11.24 - ETA: 3:23 - loss: 11.20 - ETA: 3:26 - loss: 11.16 - ETA: 3:24 - loss: 11.12 - ETA: 3:23 - loss: 11.13 - ETA: 3:22 - loss: 11.10 - ETA: 3:25 - loss: 11.09 - ETA: 3:24 - loss: 11.07 - ETA: 3:23 - loss: 11.04 - ETA: 3:26 - loss: 11.02 - ETA: 3:23 - loss: 10.99 - ETA: 3:22 - loss: 10.99 - ETA: 3:23 - loss: 10.97 - ETA: 3:13 - loss: 11.00 - ETA: 3:14 - loss: 10.99 - ETA: 3:13 - loss: 10.97 - ETA: 3:11 - loss: 10.96 - ETA: 3:09 - loss: 10.96 - ETA: 3:06 - loss: 10.95 - ETA: 3:02 - loss: 10.96 - ETA: 2:59 - loss: 10.96 - ETA: 2:56 - loss: 10.96 - ETA: 2:53 - loss: 10.96 - ETA: 2:50 - loss: 10.99 - ETA: 2:47 - loss: 10.98 - ETA: 2:45 - loss: 10.99 - ETA: 2:41 - loss: 10.97 - ETA: 2:39 - loss: 10.99 - ETA: 2:36 - loss: 10.97 - ETA: 2:33 - loss: 10.97 - ETA: 2:30 - loss: 10.96 - ETA: 2:27 - loss: 10.95 - ETA: 2:25 - loss: 10.95 - ETA: 2:22 - loss: 10.93 - ETA: 2:19 - loss: 10.92 - ETA: 2:16 - loss: 10.92 - ETA: 2:13 - loss: 10.91 - ETA: 2:11 - loss: 10.91 - ETA: 2:08 - loss: 10.94 - ETA: 2:05 - loss: 10.93 - ETA: 2:03 - loss: 10.92 - ETA: 2:00 - loss: 10.91 - ETA: 1:58 - loss: 10.92 - ETA: 1:55 - loss: 10.91 - ETA: 1:52 - loss: 10.90 - ETA: 1:50 - loss: 10.90 - ETA: 1:47 - loss: 10.90 - ETA: 1:44 - loss: 10.89 - ETA: 1:42 - loss: 10.91 - ETA: 1:39 - loss: 10.91 - ETA: 1:36 - loss: 10.91 - ETA: 1:34 - loss: 10.92 - ETA: 1:31 - loss: 10.91 - ETA: 1:28 - loss: 10.90 - ETA: 1:26 - loss: 10.90 - ETA: 1:23 - loss: 10.90 - ETA: 1:21 - loss: 10.90 - ETA: 1:18 - loss: 10.90 - ETA: 1:15 - loss: 10.90 - ETA: 1:13 - loss: 10.90 - ETA: 1:10 - loss: 10.89 - ETA: 1:08 - loss: 10.92 - ETA: 1:05 - loss: 10.92 - ETA: 1:02 - loss: 10.91 - ETA: 1:00 - loss: 10.91 - ETA: 57s - loss: 10.9060 - ETA: 54s - loss: 10.910 - ETA: 52s - loss: 10.905 - ETA: 49s - loss: 10.912 - ETA: 46s - loss: 10.912 - ETA: 44s - loss: 10.910 - ETA: 41s - loss: 10.909 - ETA: 39s - loss: 10.914 - ETA: 36s - loss: 10.925 - ETA: 33s - loss: 10.927 - ETA: 31s - loss: 10.921 - ETA: 28s - loss: 10.919 - ETA: 26s - loss: 10.914 - ETA: 23s - loss: 10.926 - ETA: 20s - loss: 10.919 - ETA: 18s - loss: 10.917 - ETA: 15s - loss: 10.929 - ETA: 12s - loss: 10.924 - ETA: 10s - loss: 10.936 - ETA: 7s - loss: 10.934 - ETA: 5s - loss: 10.92 - ETA: 2s - loss: 10.92 - 280s 3s/step - loss: 10.9220 - val_loss: 11.0748
#
# Epoch 00014: val_loss improved from 11.16955 to 11.07476, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-14_loss-10.9148_val_loss-11.0748.h5
# Epoch 15/120
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:13 - loss: 10.55 - ETA: 1:13 - loss: 10.44 - ETA: 1:11 - loss: 10.53 - ETA: 1:12 - loss: 10.73 - ETA: 1:10 - loss: 10.66 - ETA: 1:10 - loss: 10.69 - ETA: 1:50 - loss: 10.66 - ETA: 2:25 - loss: 10.70 - ETA: 2:50 - loss: 10.82 - ETA: 3:03 - loss: 10.87 - ETA: 3:06 - loss: 10.79 - ETA: 3:08 - loss: 10.84 - ETA: 3:11 - loss: 10.94 - ETA: 3:13 - loss: 10.91 - ETA: 3:15 - loss: 10.86 - ETA: 3:17 - loss: 10.85 - ETA: 3:16 - loss: 10.85 - ETA: 3:17 - loss: 10.85 - ETA: 3:16 - loss: 10.92 - ETA: 3:16 - loss: 10.90 - ETA: 3:16 - loss: 10.86 - ETA: 3:16 - loss: 10.85 - ETA: 3:16 - loss: 10.82 - ETA: 3:17 - loss: 10.78 - ETA: 3:15 - loss: 10.77 - ETA: 3:15 - loss: 10.76 - ETA: 3:13 - loss: 10.78 - ETA: 3:05 - loss: 10.79 - ETA: 3:04 - loss: 10.80 - ETA: 3:03 - loss: 10.77 - ETA: 3:04 - loss: 10.78 - ETA: 3:02 - loss: 10.80 - ETA: 3:01 - loss: 10.80 - ETA: 3:00 - loss: 10.82 - ETA: 2:58 - loss: 10.81 - ETA: 2:55 - loss: 10.79 - ETA: 2:53 - loss: 10.77 - ETA: 2:50 - loss: 10.75 - ETA: 2:48 - loss: 10.80 - ETA: 2:45 - loss: 10.82 - ETA: 2:42 - loss: 10.83 - ETA: 2:40 - loss: 10.82 - ETA: 2:38 - loss: 10.81 - ETA: 2:35 - loss: 10.81 - ETA: 2:33 - loss: 10.79 - ETA: 2:31 - loss: 10.79 - ETA: 2:28 - loss: 10.78 - ETA: 2:26 - loss: 10.79 - ETA: 2:24 - loss: 10.80 - ETA: 2:21 - loss: 10.79 - ETA: 2:18 - loss: 10.81 - ETA: 2:16 - loss: 10.81 - ETA: 2:13 - loss: 10.82 - ETA: 2:11 - loss: 10.82 - ETA: 2:08 - loss: 10.82 - ETA: 2:05 - loss: 10.81 - ETA: 2:02 - loss: 10.80 - ETA: 1:59 - loss: 10.81 - ETA: 1:56 - loss: 10.81 - ETA: 1:53 - loss: 10.80 - ETA: 1:50 - loss: 10.80 - ETA: 1:48 - loss: 10.80 - ETA: 1:46 - loss: 10.80 - ETA: 1:44 - loss: 10.81 - ETA: 1:41 - loss: 10.80 - ETA: 1:39 - loss: 10.81 - ETA: 1:36 - loss: 10.83 - ETA: 1:33 - loss: 10.84 - ETA: 1:30 - loss: 10.83 - ETA: 1:27 - loss: 10.86 - ETA: 1:24 - loss: 10.85 - ETA: 1:21 - loss: 10.85 - ETA: 1:19 - loss: 10.85 - ETA: 1:16 - loss: 10.84 - ETA: 1:13 - loss: 10.84 - ETA: 1:10 - loss: 10.83 - ETA: 1:07 - loss: 10.84 - ETA: 1:04 - loss: 10.85 - ETA: 1:01 - loss: 10.84 - ETA: 58s - loss: 10.8440 - ETA: 55s - loss: 10.830 - ETA: 52s - loss: 10.829 - ETA: 49s - loss: 10.830 - ETA: 46s - loss: 10.826 - ETA: 43s - loss: 10.818 - ETA: 40s - loss: 10.824 - ETA: 37s - loss: 10.821 - ETA: 34s - loss: 10.821 - ETA: 32s - loss: 10.822 - ETA: 29s - loss: 10.814 - ETA: 26s - loss: 10.824 - ETA: 23s - loss: 10.834 - ETA: 20s - loss: 10.832 - ETA: 17s - loss: 10.824 - ETA: 14s - loss: 10.816 - ETA: 11s - loss: 10.808 - ETA: 8s - loss: 10.804 - ETA: 5s - loss: 10.79 - ETA: 2s - loss: 10.79 - 311s 3s/step - loss: 10.7953 - val_loss: 10.8568
#
# Epoch 00015: val_loss improved from 11.07476 to 10.85675, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-15_loss-10.7944_val_loss-10.8568.h5
# Epoch 16/120
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 100/100 [==============================] - ETA: 1:09 - loss: 10.05 - ETA: 1:10 - loss: 10.25 - ETA: 1:09 - loss: 10.27 - ETA: 1:10 - loss: 10.29 - ETA: 1:10 - loss: 10.27 - ETA: 1:17 - loss: 10.60 - ETA: 1:59 - loss: 10.58 - ETA: 2:26 - loss: 10.61 - ETA: 2:46 - loss: 10.74 - ETA: 2:54 - loss: 10.66 - ETA: 3:00 - loss: 10.63 - ETA: 3:04 - loss: 10.61 - ETA: 3:06 - loss: 10.60 - ETA: 3:08 - loss: 10.59 - ETA: 3:08 - loss: 10.56 - ETA: 3:09 - loss: 10.54 - ETA: 3:09 - loss: 10.58 - ETA: 3:09 - loss: 10.58 - ETA: 3:09 - loss: 10.58 - ETA: 3:07 - loss: 10.64 - ETA: 3:05 - loss: 10.63 - ETA: 3:03 - loss: 10.62 - ETA: 3:02 - loss: 10.61 - ETA: 3:00 - loss: 10.61 - ETA: 2:59 - loss: 10.60 - ETA: 2:57 - loss: 10.59 - ETA: 2:55 - loss: 10.66 - ETA: 2:53 - loss: 10.64 - ETA: 2:51 - loss: 10.65 - ETA: 2:44 - loss: 10.77 - ETA: 2:42 - loss: 10.75 - ETA: 2:40 - loss: 10.76 - ETA: 2:38 - loss: 10.79 - ETA: 2:36 - loss: 10.79 - ETA: 2:34 - loss: 10.77 - ETA: 2:32 - loss: 10.80 - ETA: 2:31 - loss: 10.82 - ETA: 2:29 - loss: 10.83 - ETA: 2:27 - loss: 10.83 - ETA: 2:25 - loss: 10.83 - ETA: 2:22 - loss: 10.83 - ETA: 2:20 - loss: 10.82 - ETA: 2:17 - loss: 10.81 - ETA: 2:14 - loss: 10.81 - ETA: 2:12 - loss: 10.79 - ETA: 2:09 - loss: 10.79 - ETA: 2:07 - loss: 10.81 - ETA: 2:04 - loss: 10.82 - ETA: 2:02 - loss: 10.82 - ETA: 1:59 - loss: 10.81 - ETA: 1:57 - loss: 10.81 - ETA: 1:54 - loss: 10.80 - ETA: 1:51 - loss: 10.82 - ETA: 1:47 - loss: 10.83 - ETA: 1:44 - loss: 10.85 - ETA: 1:42 - loss: 10.85 - ETA: 1:40 - loss: 10.83 - ETA: 1:37 - loss: 10.83 - ETA: 1:35 - loss: 10.86 - ETA: 1:33 - loss: 10.87 - ETA: 1:31 - loss: 10.87 - ETA: 1:28 - loss: 10.86 - ETA: 1:26 - loss: 10.85 - ETA: 1:24 - loss: 10.84 - ETA: 1:22 - loss: 10.84 - ETA: 1:19 - loss: 10.83 - ETA: 1:17 - loss: 10.82 - ETA: 1:15 - loss: 10.81 - ETA: 1:12 - loss: 10.80 - ETA: 1:10 - loss: 10.80 - ETA: 1:08 - loss: 10.79 - ETA: 1:05 - loss: 10.78 - ETA: 1:03 - loss: 10.78 - ETA: 1:01 - loss: 10.78 - ETA: 58s - loss: 10.7784 - ETA: 56s - loss: 10.773 - ETA: 54s - loss: 10.767 - ETA: 51s - loss: 10.760 - ETA: 49s - loss: 10.754 - ETA: 47s - loss: 10.756 - ETA: 44s - loss: 10.748 - ETA: 42s - loss: 10.746 - ETA: 40s - loss: 10.737 - ETA: 37s - loss: 10.733 - ETA: 35s - loss: 10.745 - ETA: 33s - loss: 10.738 - ETA: 30s - loss: 10.734 - ETA: 28s - loss: 10.728 - ETA: 25s - loss: 10.733 - ETA: 23s - loss: 10.732 - ETA: 21s - loss: 10.733 - ETA: 18s - loss: 10.726 - ETA: 16s - loss: 10.725 - ETA: 14s - loss: 10.718 - ETA: 11s - loss: 10.709 - ETA: 9s - loss: 10.708 - ETA: 7s - loss: 10.70 - ETA: 4s - loss: 10.69 - ETA: 2s - loss: 10.69 - 256s 3s/step - loss: 10.6895 - val_loss: 10.7630
#
# Epoch 00016: val_loss improved from 10.85675 to 10.76301, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-16_loss-10.6595_val_loss-10.7630.h5
# Epoch 17/120
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# ...
#
# Epoch 00115: val_loss improved from 5.37513 to 5.37219, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-115_loss-5.1567_val_loss-5.3722.h5
# Epoch 116/120
#
# Epoch 00116: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - ETA: 1:06 - loss: 5.409 - ETA: 1:09 - loss: 5.130 - ETA: 1:10 - loss: 5.081 - ETA: 1:12 - loss: 5.003 - ETA: 1:11 - loss: 5.088 - ETA: 1:09 - loss: 5.098 - ETA: 1:51 - loss: 5.213 - ETA: 2:20 - loss: 5.167 - ETA: 2:41 - loss: 5.233 - ETA: 2:46 - loss: 5.255 - ETA: 2:49 - loss: 5.167 - ETA: 2:52 - loss: 5.198 - ETA: 2:51 - loss: 5.201 - ETA: 2:52 - loss: 5.195 - ETA: 2:51 - loss: 5.205 - ETA: 2:50 - loss: 5.181 - ETA: 2:49 - loss: 5.185 - ETA: 2:48 - loss: 5.191 - ETA: 2:47 - loss: 5.154 - ETA: 2:46 - loss: 5.133 - ETA: 2:43 - loss: 5.126 - ETA: 2:43 - loss: 5.127 - ETA: 2:42 - loss: 5.113 - ETA: 2:41 - loss: 5.136 - ETA: 2:40 - loss: 5.125 - ETA: 2:32 - loss: 5.158 - ETA: 2:31 - loss: 5.139 - ETA: 2:30 - loss: 5.146 - ETA: 2:29 - loss: 5.145 - ETA: 2:27 - loss: 5.159 - ETA: 2:25 - loss: 5.155 - ETA: 2:24 - loss: 5.158 - ETA: 2:21 - loss: 5.140 - ETA: 2:19 - loss: 5.132 - ETA: 2:18 - loss: 5.168 - ETA: 2:16 - loss: 5.159 - ETA: 2:14 - loss: 5.147 - ETA: 2:12 - loss: 5.146 - ETA: 2:10 - loss: 5.156 - ETA: 2:08 - loss: 5.139 - ETA: 2:06 - loss: 5.158 - ETA: 2:04 - loss: 5.159 - ETA: 2:02 - loss: 5.151 - ETA: 2:01 - loss: 5.152 - ETA: 1:59 - loss: 5.152 - ETA: 1:57 - loss: 5.147 - ETA: 1:55 - loss: 5.165 - ETA: 1:53 - loss: 5.163 - ETA: 1:51 - loss: 5.174 - ETA: 1:49 - loss: 5.171 - ETA: 1:47 - loss: 5.177 - ETA: 1:45 - loss: 5.166 - ETA: 1:42 - loss: 5.160 - ETA: 1:40 - loss: 5.144 - ETA: 1:38 - loss: 5.153 - ETA: 1:36 - loss: 5.193 - ETA: 1:34 - loss: 5.231 - ETA: 1:32 - loss: 5.224 - ETA: 1:29 - loss: 5.265 - ETA: 1:27 - loss: 5.255 - ETA: 1:25 - loss: 5.251 - ETA: 1:23 - loss: 5.244 - ETA: 1:21 - loss: 5.239 - ETA: 1:19 - loss: 5.233 - ETA: 1:17 - loss: 5.220 - ETA: 1:15 - loss: 5.217 - ETA: 1:13 - loss: 5.211 - ETA: 1:10 - loss: 5.196 - ETA: 1:08 - loss: 5.197 - ETA: 1:06 - loss: 5.192 - ETA: 1:04 - loss: 5.186 - ETA: 1:02 - loss: 5.199 - ETA: 59s - loss: 5.201 - ETA: 57s - loss: 5.19 - ETA: 55s - loss: 5.20 - ETA: 53s - loss: 5.19 - ETA: 51s - loss: 5.19 - ETA: 49s - loss: 5.20 - ETA: 46s - loss: 5.20 - ETA: 44s - loss: 5.20 - ETA: 42s - loss: 5.20 - ETA: 40s - loss: 5.20 - ETA: 38s - loss: 5.19 - ETA: 35s - loss: 5.19 - ETA: 33s - loss: 5.19 - ETA: 31s - loss: 5.20 - ETA: 29s - loss: 5.22 - ETA: 26s - loss: 5.22 - ETA: 24s - loss: 5.22 - ETA: 22s - loss: 5.22 - ETA: 20s - loss: 5.21 - ETA: 17s - loss: 5.24 - ETA: 15s - loss: 5.25 - ETA: 13s - loss: 5.24 - ETA: 11s - loss: 5.25 - ETA: 9s - loss: 5.2715 - ETA: 6s - loss: 5.265 - ETA: 4s - loss: 5.267 - ETA: 2s - loss: 5.264 - 243s 2s/step - loss: 5.2994 - val_loss: 5.3705
#
# Epoch 00116: val_loss improved from 5.37219 to 5.37049, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-116_loss-5.2933_val_loss-5.3705.h5
# Epoch 117/120
#
# Epoch 00117: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - ETA: 1:18 - loss: 5.750 - ETA: 1:16 - loss: 5.469 - ETA: 1:14 - loss: 5.271 - ETA: 1:12 - loss: 5.192 - ETA: 1:12 - loss: 5.162 - ETA: 1:19 - loss: 5.320 - ETA: 2:00 - loss: 5.257 - ETA: 2:22 - loss: 5.183 - ETA: 2:41 - loss: 5.192 - ETA: 2:44 - loss: 5.182 - ETA: 2:47 - loss: 5.180 - ETA: 2:49 - loss: 5.140 - ETA: 2:51 - loss: 5.123 - ETA: 2:50 - loss: 5.088 - ETA: 2:50 - loss: 5.128 - ETA: 2:47 - loss: 5.081 - ETA: 2:48 - loss: 5.053 - ETA: 2:48 - loss: 5.058 - ETA: 2:46 - loss: 5.060 - ETA: 2:46 - loss: 5.040 - ETA: 2:46 - loss: 5.030 - ETA: 2:45 - loss: 5.046 - ETA: 2:44 - loss: 5.098 - ETA: 2:44 - loss: 5.141 - ETA: 2:43 - loss: 5.132 - ETA: 2:40 - loss: 5.116 - ETA: 2:39 - loss: 5.108 - ETA: 2:32 - loss: 5.060 - ETA: 2:31 - loss: 5.049 - ETA: 2:28 - loss: 5.039 - ETA: 2:27 - loss: 5.036 - ETA: 2:25 - loss: 5.057 - ETA: 2:23 - loss: 5.058 - ETA: 2:21 - loss: 5.074 - ETA: 2:20 - loss: 5.078 - ETA: 2:18 - loss: 5.078 - ETA: 2:16 - loss: 5.083 - ETA: 2:14 - loss: 5.085 - ETA: 2:12 - loss: 5.068 - ETA: 2:10 - loss: 5.056 - ETA: 2:08 - loss: 5.062 - ETA: 2:06 - loss: 5.088 - ETA: 2:04 - loss: 5.081 - ETA: 2:01 - loss: 5.076 - ETA: 1:59 - loss: 5.076 - ETA: 1:57 - loss: 5.112 - ETA: 1:55 - loss: 5.109 - ETA: 1:53 - loss: 5.102 - ETA: 1:51 - loss: 5.087 - ETA: 1:49 - loss: 5.089 - ETA: 1:47 - loss: 5.082 - ETA: 1:45 - loss: 5.093 - ETA: 1:43 - loss: 5.089 - ETA: 1:40 - loss: 5.096 - ETA: 1:38 - loss: 5.090 - ETA: 1:36 - loss: 5.085 - ETA: 1:34 - loss: 5.085 - ETA: 1:32 - loss: 5.088 - ETA: 1:30 - loss: 5.094 - ETA: 1:28 - loss: 5.088 - ETA: 1:26 - loss: 5.084 - ETA: 1:23 - loss: 5.088 - ETA: 1:21 - loss: 5.087 - ETA: 1:19 - loss: 5.100 - ETA: 1:17 - loss: 5.122 - ETA: 1:15 - loss: 5.143 - ETA: 1:13 - loss: 5.141 - ETA: 1:10 - loss: 5.137 - ETA: 1:08 - loss: 5.136 - ETA: 1:06 - loss: 5.137 - ETA: 1:04 - loss: 5.126 - ETA: 1:02 - loss: 5.127 - ETA: 1:00 - loss: 5.126 - ETA: 57s - loss: 5.130 - ETA: 55s - loss: 5.13 - ETA: 53s - loss: 5.14 - ETA: 51s - loss: 5.14 - ETA: 49s - loss: 5.17 - ETA: 46s - loss: 5.17 - ETA: 44s - loss: 5.16 - ETA: 42s - loss: 5.16 - ETA: 40s - loss: 5.18 - ETA: 37s - loss: 5.18 - ETA: 35s - loss: 5.19 - ETA: 33s - loss: 5.20 - ETA: 31s - loss: 5.20 - ETA: 29s - loss: 5.21 - ETA: 26s - loss: 5.23 - ETA: 24s - loss: 5.22 - ETA: 22s - loss: 5.24 - ETA: 20s - loss: 5.24 - ETA: 18s - loss: 5.24 - ETA: 15s - loss: 5.23 - ETA: 13s - loss: 5.23 - ETA: 11s - loss: 5.23 - ETA: 9s - loss: 5.2516 - ETA: 6s - loss: 5.250 - ETA: 4s - loss: 5.245 - ETA: 2s - loss: 5.238 - 245s 2s/step - loss: 5.2347 - val_loss: 5.3674
#
# Epoch 00117: val_loss improved from 5.37049 to 5.36743, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-117_loss-5.2475_val_loss-5.3674.h5
# Epoch 118/120
#
# Epoch 00118: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - ETA: 1:09 - loss: 4.985 - ETA: 1:10 - loss: 4.983 - ETA: 1:10 - loss: 5.240 - ETA: 1:10 - loss: 5.171 - ETA: 1:11 - loss: 5.234 - ETA: 1:10 - loss: 5.155 - ETA: 1:42 - loss: 5.137 - ETA: 2:06 - loss: 5.171 - ETA: 2:26 - loss: 5.263 - ETA: 2:34 - loss: 5.190 - ETA: 2:37 - loss: 5.208 - ETA: 2:40 - loss: 5.185 - ETA: 2:41 - loss: 5.130 - ETA: 2:41 - loss: 5.109 - ETA: 2:42 - loss: 5.103 - ETA: 2:42 - loss: 5.115 - ETA: 2:42 - loss: 5.102 - ETA: 2:43 - loss: 5.095 - ETA: 2:43 - loss: 5.062 - ETA: 2:42 - loss: 5.041 - ETA: 2:42 - loss: 5.130 - ETA: 2:39 - loss: 5.146 - ETA: 2:37 - loss: 5.141 - ETA: 2:35 - loss: 5.144 - ETA: 2:33 - loss: 5.166 - ETA: 2:32 - loss: 5.175 - ETA: 2:30 - loss: 5.177 - ETA: 2:28 - loss: 5.176 - ETA: 2:27 - loss: 5.181 - ETA: 2:21 - loss: 5.173 - ETA: 2:20 - loss: 5.169 - ETA: 2:18 - loss: 5.155 - ETA: 2:16 - loss: 5.147 - ETA: 2:16 - loss: 5.160 - ETA: 2:14 - loss: 5.145 - ETA: 2:12 - loss: 5.136 - ETA: 2:11 - loss: 5.146 - ETA: 2:10 - loss: 5.135 - ETA: 2:08 - loss: 5.136 - ETA: 2:06 - loss: 5.123 - ETA: 2:04 - loss: 5.114 - ETA: 2:02 - loss: 5.099 - ETA: 2:00 - loss: 5.110 - ETA: 1:58 - loss: 5.119 - ETA: 1:56 - loss: 5.108 - ETA: 1:54 - loss: 5.138 - ETA: 1:52 - loss: 5.136 - ETA: 1:50 - loss: 5.167 - ETA: 1:48 - loss: 5.161 - ETA: 1:47 - loss: 5.154 - ETA: 1:45 - loss: 5.146 - ETA: 1:43 - loss: 5.140 - ETA: 1:41 - loss: 5.136 - ETA: 1:39 - loss: 5.144 - ETA: 1:37 - loss: 5.149 - ETA: 1:35 - loss: 5.161 - ETA: 1:33 - loss: 5.153 - ETA: 1:31 - loss: 5.153 - ETA: 1:29 - loss: 5.154 - ETA: 1:27 - loss: 5.153 - ETA: 1:25 - loss: 5.156 - ETA: 1:23 - loss: 5.155 - ETA: 1:20 - loss: 5.160 - ETA: 1:18 - loss: 5.176 - ETA: 1:16 - loss: 5.173 - ETA: 1:14 - loss: 5.173 - ETA: 1:12 - loss: 5.170 - ETA: 1:10 - loss: 5.184 - ETA: 1:08 - loss: 5.219 - ETA: 1:06 - loss: 5.217 - ETA: 1:03 - loss: 5.229 - ETA: 1:01 - loss: 5.227 - ETA: 59s - loss: 5.226 - ETA: 57s - loss: 5.22 - ETA: 55s - loss: 5.25 - ETA: 53s - loss: 5.25 - ETA: 50s - loss: 5.27 - ETA: 48s - loss: 5.27 - ETA: 46s - loss: 5.27 - ETA: 44s - loss: 5.27 - ETA: 42s - loss: 5.26 - ETA: 39s - loss: 5.26 - ETA: 37s - loss: 5.26 - ETA: 35s - loss: 5.25 - ETA: 33s - loss: 5.25 - ETA: 31s - loss: 5.24 - ETA: 28s - loss: 5.24 - ETA: 26s - loss: 5.24 - ETA: 24s - loss: 5.24 - ETA: 22s - loss: 5.24 - ETA: 20s - loss: 5.24 - ETA: 17s - loss: 5.25 - ETA: 15s - loss: 5.24 - ETA: 13s - loss: 5.24 - ETA: 11s - loss: 5.24 - ETA: 8s - loss: 5.2402 - ETA: 6s - loss: 5.233 - ETA: 4s - loss: 5.232 - ETA: 2s - loss: 5.226 - 243s 2s/step - loss: 5.2268 - val_loss: 5.3664
#
# Epoch 00118: val_loss improved from 5.36743 to 5.36641, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-118_loss-5.2293_val_loss-5.3664.h5
# Epoch 119/120
#
# Epoch 00119: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - ETA: 1:08 - loss: 4.978 - ETA: 1:11 - loss: 5.041 - ETA: 1:09 - loss: 5.061 - ETA: 1:09 - loss: 4.966 - ETA: 1:09 - loss: 4.911 - ETA: 1:15 - loss: 4.901 - ETA: 1:49 - loss: 4.819 - ETA: 2:14 - loss: 4.793 - ETA: 2:33 - loss: 4.852 - ETA: 2:36 - loss: 4.834 - ETA: 2:38 - loss: 4.971 - ETA: 2:41 - loss: 5.057 - ETA: 2:42 - loss: 5.041 - ETA: 2:43 - loss: 5.055 - ETA: 2:44 - loss: 5.062 - ETA: 2:44 - loss: 5.047 - ETA: 2:43 - loss: 5.074 - ETA: 2:41 - loss: 5.071 - ETA: 2:41 - loss: 5.077 - ETA: 2:41 - loss: 5.225 - ETA: 2:38 - loss: 5.229 - ETA: 2:37 - loss: 5.231 - ETA: 2:36 - loss: 5.200 - ETA: 2:35 - loss: 5.256 - ETA: 2:34 - loss: 5.235 - ETA: 2:33 - loss: 5.226 - ETA: 2:31 - loss: 5.221 - ETA: 2:30 - loss: 5.208 - ETA: 2:28 - loss: 5.199 - ETA: 2:26 - loss: 5.183 - ETA: 2:24 - loss: 5.180 - ETA: 2:18 - loss: 5.195 - ETA: 2:17 - loss: 5.183 - ETA: 2:16 - loss: 5.181 - ETA: 2:15 - loss: 5.175 - ETA: 2:13 - loss: 5.186 - ETA: 2:13 - loss: 5.193 - ETA: 2:10 - loss: 5.221 - ETA: 2:09 - loss: 5.294 - ETA: 2:07 - loss: 5.285 - ETA: 2:04 - loss: 5.270 - ETA: 2:03 - loss: 5.267 - ETA: 2:01 - loss: 5.272 - ETA: 1:58 - loss: 5.258 - ETA: 1:56 - loss: 5.249 - ETA: 1:54 - loss: 5.313 - ETA: 1:53 - loss: 5.319 - ETA: 1:51 - loss: 5.316 - ETA: 1:49 - loss: 5.310 - ETA: 1:47 - loss: 5.309 - ETA: 1:45 - loss: 5.306 - ETA: 1:43 - loss: 5.299 - ETA: 1:41 - loss: 5.299 - ETA: 1:39 - loss: 5.287 - ETA: 1:37 - loss: 5.276 - ETA: 1:35 - loss: 5.269 - ETA: 1:32 - loss: 5.271 - ETA: 1:30 - loss: 5.261 - ETA: 1:28 - loss: 5.260 - ETA: 1:26 - loss: 5.251 - ETA: 1:24 - loss: 5.240 - ETA: 1:22 - loss: 5.231 - ETA: 1:20 - loss: 5.224 - ETA: 1:17 - loss: 5.224 - ETA: 1:15 - loss: 5.264 - ETA: 1:13 - loss: 5.268 - ETA: 1:11 - loss: 5.256 - ETA: 1:09 - loss: 5.251 - ETA: 1:07 - loss: 5.241 - ETA: 1:05 - loss: 5.240 - ETA: 1:03 - loss: 5.237 - ETA: 1:01 - loss: 5.241 - ETA: 59s - loss: 5.238 - ETA: 57s - loss: 5.24 - ETA: 55s - loss: 5.24 - ETA: 53s - loss: 5.24 - ETA: 50s - loss: 5.23 - ETA: 48s - loss: 5.23 - ETA: 46s - loss: 5.23 - ETA: 44s - loss: 5.23 - ETA: 41s - loss: 5.24 - ETA: 39s - loss: 5.24 - ETA: 37s - loss: 5.23 - ETA: 35s - loss: 5.23 - ETA: 32s - loss: 5.23 - ETA: 30s - loss: 5.22 - ETA: 28s - loss: 5.22 - ETA: 26s - loss: 5.24 - ETA: 24s - loss: 5.24 - ETA: 21s - loss: 5.23 - ETA: 19s - loss: 5.23 - ETA: 17s - loss: 5.23 - ETA: 15s - loss: 5.22 - ETA: 13s - loss: 5.22 - ETA: 11s - loss: 5.22 - ETA: 8s - loss: 5.2571 - ETA: 6s - loss: 5.265 - ETA: 4s - loss: 5.263 - ETA: 2s - loss: 5.259 - 240s 2s/step - loss: 5.2551 - val_loss: 5.3614
#
# Epoch 00119: val_loss improved from 5.36641 to 5.36144, saving model to D:\xgll\ssd_keras_weights\coco_train_300\ssd_epoch-119_loss-5.2516_val_loss-5.3614.h5
# Epoch 120/120
#
# Epoch 00120: LearningRateScheduler setting learning rate to 1e-05.
# 100/100 [==============================] - ETA: 1:02 - loss: 6.992 - ETA: 1:10 - loss: 6.449 - ETA: 1:09 - loss: 6.066 - ETA: 1:09 - loss: 5.844 - ETA: 1:11 - loss: 5.572 - ETA: 1:17 - loss: 5.670 - ETA: 1:46 - loss: 5.791 - ETA: 2:14 - loss: 5.705 - ETA: 2:32 - loss: 5.753 - ETA: 2:34 - loss: 5.663 - ETA: 2:36 - loss: 5.621 - ETA: 2:39 - loss: 5.574 - ETA: 2:42 - loss: 5.557 - ETA: 2:45 - loss: 5.533 - ETA: 2:46 - loss: 5.468 - ETA: 2:44 - loss: 5.431 - ETA: 2:44 - loss: 5.403 - ETA: 2:43 - loss: 5.380 - ETA: 2:42 - loss: 5.371 - ETA: 2:42 - loss: 5.328 - ETA: 2:41 - loss: 5.312 - ETA: 2:41 - loss: 5.284 - ETA: 2:40 - loss: 5.295 - ETA: 2:38 - loss: 5.360 - ETA: 2:37 - loss: 5.344 - ETA: 2:36 - loss: 5.369 - ETA: 2:34 - loss: 5.360 - ETA: 2:32 - loss: 5.347 - ETA: 2:30 - loss: 5.355 - ETA: 2:29 - loss: 5.354 - ETA: 2:27 - loss: 5.340 - ETA: 2:25 - loss: 5.333 - ETA: 2:24 - loss: 5.362 - ETA: 2:18 - loss: 5.339 - ETA: 2:17 - loss: 5.309 - ETA: 2:15 - loss: 5.303 - ETA: 2:13 - loss: 5.378 - ETA: 2:11 - loss: 5.372 - ETA: 2:09 - loss: 5.359 - ETA: 2:07 - loss: 5.355 - ETA: 2:06 - loss: 5.337 - ETA: 2:04 - loss: 5.331 - ETA: 2:03 - loss: 5.359 - ETA: 2:01 - loss: 5.359 - ETA: 1:59 - loss: 5.349 - ETA: 1:56 - loss: 5.338 - ETA: 1:55 - loss: 5.333 - ETA: 1:53 - loss: 5.330 - ETA: 1:51 - loss: 5.345 - ETA: 1:49 - loss: 5.337 - ETA: 1:47 - loss: 5.367 - ETA: 1:44 - loss: 5.354 - ETA: 1:42 - loss: 5.347 - ETA: 1:40 - loss: 5.350 - ETA: 1:38 - loss: 5.344 - ETA: 1:36 - loss: 5.340 - ETA: 1:34 - loss: 5.353 - ETA: 1:32 - loss: 5.350 - ETA: 1:29 - loss: 5.337 - ETA: 1:27 - loss: 5.331 - ETA: 1:25 - loss: 5.323 - ETA: 1:23 - loss: 5.315 - ETA: 1:20 - loss: 5.314 - ETA: 1:18 - loss: 5.310 - ETA: 1:16 - loss: 5.300 - ETA: 1:14 - loss: 5.334 - ETA: 1:12 - loss: 5.334 - ETA: 1:10 - loss: 5.331 - ETA: 1:08 - loss: 5.338 - ETA: 1:06 - loss: 5.328 - ETA: 1:03 - loss: 5.321 - ETA: 1:01 - loss: 5.319 - ETA: 59s - loss: 5.318 - ETA: 57s - loss: 5.31 - ETA: 55s - loss: 5.31 - ETA: 52s - loss: 5.32 - ETA: 50s - loss: 5.32 - ETA: 48s - loss: 5.31 - ETA: 46s - loss: 5.32 - ETA: 44s - loss: 5.32 - ETA: 42s - loss: 5.33 - ETA: 39s - loss: 5.32 - ETA: 37s - loss: 5.32 - ETA: 35s - loss: 5.31 - ETA: 33s - loss: 5.30 - ETA: 31s - loss: 5.30 - ETA: 28s - loss: 5.29 - ETA: 26s - loss: 5.30 - ETA: 24s - loss: 5.30 - ETA: 22s - loss: 5.30 - ETA: 20s - loss: 5.29 - ETA: 17s - loss: 5.28 - ETA: 15s - loss: 5.28 - ETA: 13s - loss: 5.27 - ETA: 11s - loss: 5.29 - ETA: 8s - loss: 5.2958 - ETA: 6s - loss: 5.305 - ETA: 4s - loss: 5.300 - ETA: 2s - loss: 5.301 - 244s 2s/step - loss: 5.2926 - val_loss: 5.3638
#
# Epoch 00120: val_loss did not improve from 5.36144

# %% [markdown]
# ## 6. Make predictions
#
# Now let's make some predictions on the validation dataset with the trained model. For convenience we'll use the validation generator that we've already set up above. Feel free to change the batch size.
#
# You can set the `shuffle` option to `False` if you would like to check the model's progress on the same image(s) over the course of the training.

# %%
# 1: Set the generator for the predictions.

predict_generator = val_dataset.generate(batch_size=1,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# %%
# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 0 # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))
# Out:
# Image: D:\xgll\dataset\dataset_300\IMG_20181101_085601R_right.jpg
#
# Ground truth boxes:
#
# [[  1  63   0 181 228]]

# %%
# 3: Make predictions.

y_pred = model.predict(batch_images)

# %% [markdown]
# Now let's decode the raw predictions in `y_pred`.
#
# Had we created the model in 'inference' or 'inference_fast' mode, then the model's final layer would be a `DecodeDetections` layer and `y_pred` would already contain the decoded predictions, but since we created the model in 'training' mode, the model outputs raw predictions that still need to be decoded and filtered. This is what the `decode_detections()` function is for. It does exactly what the `DecodeDetections` layer would do, but using Numpy instead of TensorFlow (i.e. on the CPU instead of the GPU).
#
# `decode_detections()` with default argument values follows the procedure of the original SSD implementation: First, a very low confidence threshold of 0.01 is applied to filter out the majority of the predicted boxes, then greedy non-maximum suppression is performed per class with an intersection-over-union threshold of 0.45, and out of what is left after that, the top 200 highest confidence boxes are returned. Those settings are for precision-recall scoring purposes though. In order to get some usable final predictions, we'll set the confidence threshold much higher, e.g. to 0.5, since we're only interested in the very confident predictions.

# %%
# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.5,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# %% [markdown]
# We made the predictions on the resized images, but we'd like to visualize the outcome on the original input images, so we'll convert the coordinates accordingly. Don't worry about that opaque `apply_inverse_transforms()` function below, in this simple case it just aplies `(* original_image_size / resized_image_size)` to the box coordinates.

# %%
# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])
# Out:
# Predicted boxes:
#
#    class   conf xmin   ymin   xmax   ymax
# []

# %% [markdown]
# Finally, let's draw the predicted boxes onto the image. Each predicted box says its confidence next to the category name. The ground truth boxes are also drawn onto the image in green for comparison.

# %%
# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()
classes = ['background',
           'metal', 'glass', 'stone']

plt.figure(figsize=(20,12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

for box in y_pred_decoded_inv[i]:
    xmin = box[2]
    ymin = box[3]
    xmax = box[4]
    ymax = box[5]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':color, 'alpha':1.0})
